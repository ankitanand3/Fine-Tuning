#         4.66077663e-02,  7.66887330e-03, -6.13077451e-03,  5.02090603e-02,
#        -6.47032857e-02,  5.35906246e-03, -9.11081210e-02,  2.14466825e-02,
#        -4.82286252e-02,  6.28686771e-02,  6.52390271e-02, -3.37826461e-02,
#        -6.26498535e-02, -3.32173891e-03,  4.32726145e-02, -1.56490691e-02,
#        -6.08140305e-02,  7.48930126e-02, -7.72917420e-02, -3.43159437e-02,
#         4.53204382e-03,  6.82637766e-02,  9.17027742e-02,  2.07166336e-02,
#        -3.32368724e-02, -7.15287998e-02, -1.93903334e-02,  4.24350239e-02,
#         2.08667126e-02, -2.45063566e-03,  6.61000013e-02,  4.12161574e-02,
#         1.24977371e-02, -3.50438282e-02, -4.89968769e-02, -1.03039416e-02,
#        -1.69290812e-04, -4.04090732e-02, -1.42036024e-02,  3.18816453e-02,
#        -3.45878154e-02,  7.79717937e-02, -3.41891572e-02, -2.76185130e-03,
#         5.36176600e-02, -6.74984679e-02,  9.27737507e-04, -1.36843033e-03,
#        -3.30531336e-02, -6.19068602e-03,  4.73220758e-02, -2.21568858e-03,
#        -2.66205822e-03, -2.65389662e-02, -4.38402407e-02, -3.74328555e-03,
#        -7.30669405e-03,  2.11822409e-02,  5.77979162e-03,  5.12367040e-02,
#         3.89307253e-02, -2.94828564e-02,  2.35678367e-02, -2.42014620e-02],
#       dtype=float32)

# %%
print("Embedding shape:", embedding.shape)
print("First 10 Values", np.round(embedding[:10], 6))
# Out:
# Embedding shape: (384,)
# First 10 Values [-0.031118 -0.0408    0.092715 -0.098813 -0.142078  0.000752 -0.021861
#  -0.000258 -0.043841 -0.027785]

# %%
def cosine_sim(a, b):
    return float(np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b)))

# %%
documents = [
    "Embedding fine-tuning improves retrieval in RAG.",
    "LoRA reduces GPU memory usage.",
    "My car needs fuel",
    "Vector databases store embeddings.",
]
query = "How do I improve retrieval in RAG"

# %%
doc_embs = model.encode(documents, convert_to_numpy=True)
q_emb = model.encode(query, convert_to_numpy=True)

# %%
scores = [cosine_sim(q_emb, d_emb) for d_emb in doc_embs]

# %%
for doc, score in zip(documents, scores):
    print(f"Score: {score:.4f} | {doc}")
# Out:
# Score: 0.7859 | Embedding fine-tuning improves retrieval in RAG.
# Score: 0.0779 | LoRA reduces GPU memory usage.
# Score: 0.0382 | My car needs fuel
# Score: 0.0559 | Vector databases store embeddings.

# %%
import mteb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/Documents/pp/Finetuning_HF/.venv/lib/python3.12/site-packages/torch/_ops.py:1442, in _Ops.load_library(self, path)
#    1441 try:
# -> 1442     ctypes.CDLL(path)
#    1443 except Exception as e:
#
# File /usr/lib/python3.12/ctypes/__init__.py:379, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     378 if handle is None:
# --> 379     self._handle = _dlopen(self._name, mode)
#     380 else:
#
# OSError: libc10_cuda.so: cannot open shared object file: No such file or directory
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 import mteb
#
# File ~/Documents/pp/Finetuning_HF/.venv/lib/python3.12/site-packages/mteb/__init__.py:6
#       4 from mteb.abstasks import AbsTask
#       5 from mteb.abstasks.task_metadata import TaskMetadata
# ----> 6 from mteb.cache import ResultCache
#       7 from mteb.deprecated_evaluator import MTEB
#       8 from mteb.evaluate import evaluate
#
# File ~/Documents/pp/Finetuning_HF/.venv/lib/python3.12/site-packages/mteb/cache/__init__.py:7
#       1 """MTEB Result Cache Module.
#       2
#       3 This module provides functionality for caching and managing MTEB evaluation results locally,
#       4 with support for syncing with the remote results repository on GitHub.
#       5 """
# ----> 7 from mteb.cache.result_cache import LoadExperimentEnum, ResultCache
#       9 __all__ = [
#      10     "LoadExperimentEnum",
#      11     "ResultCache",
#      12 ]
#
# File ~/Documents/pp/Finetuning_HF/.venv/lib/python3.12/site-packages/mteb/cache/result_cache.py:39
#      37 from mteb.benchmarks.get_benchmark import get_benchmark
#      38 from mteb.models import ModelMeta
# ---> 39 from mteb.models.get_model_meta import get_model_metas
#      40 from mteb.models.model_meta import _serialize_experiment_kwargs_to_name
#      41 from mteb.results import BenchmarkResults, ModelResult, TaskResult
#
# File ~/Documents/pp/Finetuning_HF/.venv/lib/python3.12/site-packages/mteb/models/get_model_meta.py:11
#       6 from typing import TYPE_CHECKING, Any
#       8 from mteb.models import (
#       9     ModelMeta,
#      10 )
# ---> 11 from mteb.models.model_implementations import MODEL_REGISTRY
#      13 if TYPE_CHECKING:
#      14     from collections.abc import Iterable, Mapping
#
# File ~/Documents/pp/Finetuning_HF/.venv/lib/python3.12/site-packages/mteb/models/model_implementations/__init__.py:39
#      34     return model_meta_objects
#      37 # build a registry of all model meta objects
#      38 MODEL_REGISTRY: dict[str, ModelMeta] = {
# ---> 39     meta.name: meta for meta in get_all_model_meta_objects()
#      40 }
#
# File ~/Documents/pp/Finetuning_HF/.venv/lib/python3.12/site-packages/mteb/models/model_implementations/__init__.py:24, in get_all_model_meta_objects()
#      21 module_name = file_path.stem
#      23 # Import the module
# ---> 24 module = importlib.import_module(f".{module_name}", package=__name__)
#      26 # Get all objects from the module that are instances of ModelMeta
#      27 for attr_name in dir(module):
#
# File /usr/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/Documents/pp/Finetuning_HF/.venv/lib/python3.12/site-packages/mteb/models/model_implementations/ast_model.py:8
#       6 import torch
#       7 from tqdm.auto import tqdm
# ----> 8 from transformers import ASTFeatureExtractor, ASTModel
#      10 from mteb.models import ModelMeta
#      11 from mteb.models.abs_encoder import AbsEncoder
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/Documents/pp/Finetuning_HF/.venv/lib/python3.12/site-packages/transformers/utils/import_utils.py:2207, in _LazyModule.__getattr__(self, name)
#    2205 elif name in self._class_to_module:
#    2206     try:
# -> 2207         module = self._get_module(self._class_to_module[name])
#    2208         value = getattr(module, name)
#    2209     except (ModuleNotFoundError, RuntimeError, AttributeError) as e:
#    2210         # V5: If trying to import a *TokenizerFast symbol, transparently fall back to the
#    2211         # non-Fast symbol from the same module when available. This lets us keep only one
#    2212         # backend tokenizer class while preserving legacy public names.
#
# File ~/Documents/pp/Finetuning_HF/.venv/lib/python3.12/site-packages/transformers/utils/import_utils.py:2441, in _LazyModule._get_module(self, module_name)
#    2439     return importlib.import_module("." + module_name, self.__name__)
#    2440 except Exception as e:
# -> 2441     raise e
#
# File ~/Documents/pp/Finetuning_HF/.venv/lib/python3.12/site-packages/transformers/utils/import_utils.py:2439, in _LazyModule._get_module(self, module_name)
#    2437 def _get_module(self, module_name: str):
#    2438     try:
# -> 2439         return importlib.import_module("." + module_name, self.__name__)
#    2440     except Exception as e:
#    2441         raise e
#
# File /usr/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/Documents/pp/Finetuning_HF/.venv/lib/python3.12/site-packages/transformers/models/audio_spectrogram_transformer/feature_extraction_audio_spectrogram_transformer.py:27
#      23 from ...utils import TensorType, is_speech_available, is_torch_available, logging
#      26 if is_speech_available():
# ---> 27     import torchaudio.compliance.kaldi as ta_kaldi
#      29 if is_torch_available():
#      30     import torch
#
# File ~/Documents/pp/Finetuning_HF/.venv/lib/python3.12/site-packages/torchaudio/__init__.py:7
#       4 import torch
#       6 # Initialize extension and backend first
# ----> 7 from . import _extension  # noqa  # usort: skip
#       8 from . import compliance, datasets, functional, models, pipelines, transforms, utils  # noqa: F401
#       9 from ._torchcodec import load_with_torchcodec, save_with_torchcodec
#
# File ~/Documents/pp/Finetuning_HF/.venv/lib/python3.12/site-packages/torchaudio/_extension/__init__.py:30
#      25     _init_dll_path()
#      27 # When the extension module is built, we initialize it.
#      28 # In case of an error, we do not catch the failure as it suggests there is something
#      29 # wrong with the installation.
# ---> 30 _IS_TORCHAUDIO_EXT_AVAILABLE = _load_lib("_torchaudio")
#      31 _IS_ALIGN_AVAILABLE = False
#      32 if _IS_TORCHAUDIO_EXT_AVAILABLE:
#
# File ~/Documents/pp/Finetuning_HF/.venv/lib/python3.12/site-packages/torchaudio/_extension/utils.py:56, in _load_lib(lib)
#      54 if len(paths) > 1:
#      55     warnings.warn(f"Expected a single file path to {lib}, got {paths=}")
# ---> 56 torch.ops.load_library(paths[0])
#      57 return True
#
# File ~/Documents/pp/Finetuning_HF/.venv/lib/python3.12/site-packages/torch/_ops.py:1444, in _Ops.load_library(self, path)
#    1442         ctypes.CDLL(path)
#    1443     except Exception as e:
# -> 1444         raise OSError(f"Could not load this library: {path}") from e
#    1445 self.loaded_libraries.add(path)
#
# OSError: Could not load this library: /home/ankitanand/Documents/pp/Finetuning_HF/.venv/lib/python3.12/site-packages/torchaudio/lib/_torchaudio.abi3.so
