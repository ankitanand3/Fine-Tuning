# %%
import gptqmodel
dir(gptqmodel)
# Out:
# INFO  LogBar: headless/AI-agent/notebook/CI environment detected; high-frequency progress bars and animations are disabled.
# WARN  Python GIL is enabled: Multi-gpu quant acceleration for MoE models is sub-optimal and multi-core accelerated cpu packing is also disabled. We recommend Python >= 3.13.3t with Pytorch > 2.8 for mult-gpu quantization and multi-cpu packing with env `PYTHON_GIL=0`.
# /home/ankitanand/Documents/pp/Finetuning_HF/.venv/lib/python3.12/site-packages/torchao/quantization/quant_api.py:1731: SyntaxWarning: invalid escape sequence '\.'
#   """Configuration class for applying different quantization configs to modules or parameters based on their fully qualified names (FQNs).
# W0801 22:29:17.942000 3598518 torch/utils/_pytree.py:630] <enum 'KernelPreference'> is an Enum subclass and is now natively supported by torch.compile as an opaque value type. Calling register_constant() on Enum subclasses is deprecated and will be an error in a future release.
# W0801 22:29:17.983000 3598518 torch/utils/_pytree.py:630] <enum 'ScaleCalculationMode'> is an Enum subclass and is now natively supported by torch.compile as an opaque value type. Calling register_constant() on Enum subclasses is deprecated and will be an error in a future release.
# INFO  ENV: Auto setting PYTORCH_ALLOC_CONF='expandable_segments:True,max_split_size_mb:256,garbage_collection_threshold:0.7' for memory saving.
# INFO  ENV: Auto setting CUDA_DEVICE_ORDER=PCI_BUS_ID for correctness.
# INFO
#
# ┌─────────────┐    ┌────────────────────────┐    ┌────────────┐    ┌─────────┐
# │ GPT-QModel  │ -> │ ▓▓▓▓▓▓▓▓▓▓▓▓ 16bit     │ -> │ ▒▒▒▒ 8bit  │ -> │ ░░ 4bit │
# └─────────────┘    └────────────────────────┘    └────────────┘    └─────────┘
# GPT-QModel   : 7.3.2+1a2fb8c
# Transformers : 5.14.1
# Torch        : 2.13.0+cu130
# Triton       : 3.7.1
# ['ASCII_LOGO',
#  'AWQConfig',
#  'BACKEND',
#  'BaseQuantizeConfig',
#  'DEBUG_ON',
#  'DEVICE_THREAD_POOL',
#  'DeviceThreadPool',
#  'FOEMConfig',
#  'GGUFConfig',
#  'GPTAQConfig',
#  'GPTQConfig',
#  'GPTQModel',
#  'PROFILE',
#  'QuantizeConfig',
#  'RTNConfig',
#  'TRANSFORMERS_VERSION',
#  'TritonPatch',
#  'WarmUpCtx',
#  'WarmupTask',
#  'WeightOnlyConfig',
#  '_DEVICE_THREAD_POOL',
#  '_LazyDeviceThreadPoolProxy',
#  '_MONKEY_PATCH_LOCK',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_banner',
#  '_build_device_thread_pool',
#  '_patch_openvino_gptqmodel_compat',
#  '_patch_transformers_causal_conv1d_hub_kernel_compat',
#  '_patch_transformers_gptq_device_map_compat',
#  '_patch_transformers_paroquant_quantizer_compat',
#  'adapter',
#  'ensure_modelscope_available',
#  'env_flag',
#  'exllama_set_max_input_length',
#  'extension',
#  'get_best_device',
#  'get_device_thread_pool',
#  'get_startup_banner',
#  'hf_kernels',
#  'looper',
#  'models',
#  'nn_modules',
#  'os',
#  'patch_safetensors_save_file',
#  'quantization',
#  'run_torch_linalg_warmup',
#  'setup_logger',
#  'sys',
#  'torch',
#  'utils',
#  'version']

# %%
from gptqmodel import GPTQModel, QuantizeConfig
from datasets import load_dataset

# %%
model = GPTQModel.load("ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5")
# Out:
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/agent-harnesses "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/1723a62d6eeb237864855301ccda0c77da970b60/config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/1723a62d6eeb237864855301ccda0c77da970b60/config.json "HTTP/1.1 200 OK"
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/1723a62d6eeb237864855301ccda0c77da970b60/config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/revision/main "HTTP/1.1 200 OK"
# from_quantized: adapter: None
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/tree/1723a62d6eeb237864855301ccda0c77da970b60?recursive=true&expand=false "HTTP/1.1 200 OK"
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/resolve/1723a62d6eeb237864855301ccda0c77da970b60/README.md "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/1723a62d6eeb237864855301ccda0c77da970b60/README.md "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/resolve/1723a62d6eeb237864855301ccda0c77da970b60/.gitattributes "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/resolve/1723a62d6eeb237864855301ccda0c77da970b60/special_tokens_map.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/resolve/1723a62d6eeb237864855301ccda0c77da970b60/quantize_config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/resolve/1723a62d6eeb237864855301ccda0c77da970b60/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/1723a62d6eeb237864855301ccda0c77da970b60/README.md "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/resolve/1723a62d6eeb237864855301ccda0c77da970b60/tokenizer.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/1723a62d6eeb237864855301ccda0c77da970b60/tokenizer_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/1723a62d6eeb237864855301ccda0c77da970b60/special_tokens_map.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/1723a62d6eeb237864855301ccda0c77da970b60/.gitattributes "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/1723a62d6eeb237864855301ccda0c77da970b60/quantize_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/1723a62d6eeb237864855301ccda0c77da970b60/.gitattributes "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/1723a62d6eeb237864855301ccda0c77da970b60/special_tokens_map.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/1723a62d6eeb237864855301ccda0c77da970b60/tokenizer.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/1723a62d6eeb237864855301ccda0c77da970b60/quantize_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/1723a62d6eeb237864855301ccda0c77da970b60/tokenizer.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/ModelCloud/Llama-3.2-1B-Instruct-gptqmodel-4bit-vortex-v2.5/1723a62d6eeb237864855301ccda0c77da970b60/tokenizer_config.json "HTTP/1.1 200 OK"
# INFO  Loader: Auto dtype (native bfloat16): `torch.bfloat16`
# INFO  QuantizeConfig: offload_to_disk_path auto set to temporary dir `/tmp/gptqmodel_ckhg9b8a`
# WARN  QuantizeConfig: `desc_act=True` automatically disables `act_group_aware`. Set `act_group_aware=False` explicitly to silence this warning.
# INFO  Estimated Quantization BPW (bits per weight): 4.85 bpw, based on [bits: 4, group_size: 32]
# INFO:tokenicer.tokenicer:Tokenicer: Auto fixed pad_token_id=128004 (token='<|finetune_right_pad_id|>').
# INFO  The layer model.embed_tokens is not quantized.
# INFO  Kernel: Auto-selection: adding candidate `MarlinLinear`
# INFO  ExLlamaV2 GPTQ: compiling torch.ops JIT extension in `/home/ankitanand/.cache/gptqmodel/torch_extensions/exllamav2/06be54f96d1b9954`.
# INFO  ExLlamaV2 GPTQ: torch.ops JIT extension ready in 12s (estimated ~35s, -22s).
# INFO  Kernel: Auto-selection: adding candidate `ExllamaV2Linear`
# INFO  Kernel: Auto-selection: adding candidate `TritonV2Linear`
# INFO  Kernel: Auto-selection: adding candidate `TorchLinear`
# INFO  Kernel: candidates -> `[MarlinLinear, ExllamaV2Linear, TritonV2Linear, TorchLinear]`
# INFO  Kernel: per-module selections -> `[MarlinLinear=112]`
# INFO  Kernel: selected -> `MarlinLinear`.
# INFO  Loader: device = DEVICE.CUDA
# INFO  Loader: Built map across 1 GPU(s), 20 entries. First 8: [('model.embed_tokens', 'cuda:0'), ('model.layers.0', 'cuda:0'), ('model.layers.1', 'cuda:0'), ('model.layers.2', 'cuda:0'), ('model.layers.3', 'cuda:0'), ('model.layers.4', 'cuda:0'), ('model.layers.5', 'cuda:0'), ('model.layers.6', 'cuda:0')]
# INFO  Loader: device_map = {'model.embed_tokens': 'cuda:0', 'model.layers.0': 'cuda:0', 'model.layers.1': 'cuda:0', 'model.layers.2': 'cuda:0', 'model.layers.3': 'cuda:0', 'model.layers.4': 'cuda:0', 'model.layers.5': 'cuda:0', 'model.layers.6': 'cuda:0', 'model.layers.7': 'cuda:0', 'model.layers.8': 'cuda:0', 'model.layers.9': 'cuda:0', 'model.layers.10': 'cuda:0', 'model.layers.11': 'cuda:0', 'model.layers.12': 'cuda:0', 'model.layers.13': 'cuda:0', 'model.layers.14': 'cuda:0', 'model.layers.15': 'cuda:0', 'lm_head': 'cuda:0', 'model.norm': 'cuda:0', 'model.rotary_emb': 'cuda:0'}
# WARNING:accelerate.utils.modeling:The model weights are not tied. Please use the `tie_weights` method before using the `infer_auto_device` function.
# INFO  Kernel: Auto-selection: adding candidate `MarlinLinear`
# INFO  Kernel: selected -> `MarlinLinear`.
# INFO  Marlin bf16: compiling torch.ops JIT extension in `/home/ankitanand/.cache/gptqmodel/torch_extensions/marlin_bf16/9dd136fef3ce1c44`.
# INFO  Marlin bf16: torch.ops JIT extension ready in 35s (estimated ~121s, -86s).
# INFO  gc.collect() reclaimed 0 objects in 0.141s
# INFO:tokenicer.tokenicer:Tokenicer: Auto fixed pad_token_id=128004 (token='<|finetune_right_pad_id|>').
# INFO  Model: Loaded `generation_config`: GenerationConfig {
#   "bos_token_id": 128000,
#   "eos_token_id": [
#     128001,
#     128008,
#     128009
#   ],
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "pad_token_id": 128004,
#   "use_cache": true
# }
#
# INFO  Model: `generation_config.json` not found. Skipped checking.
# INFO  Kernel: loaded -> `[MarlinLinear]`

# %%
result = model.generate("Hello, how are you?")[0]
# Out:
# /home/ankitanand/Documents/pp/Finetuning_HF/.venv/lib/python3.12/site-packages/transformers/generation/utils.py:1638: UserWarning: Using the model-agnostic default `max_length` (=27) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
print(model.tokenizer.decode(result))
# Out:
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# <|begin_of_text|>Hello, how are you? Today I am going to tell you the story of a beautiful, rare gemstone called the Kashmir Ruby

# %%
model_id = "unsloth/Llama-3.2-1B-Instruct"

# %%
quant_path = "Llama-3.2-1B-Instruct-gptqmodel-4bit"

# %%
caliberation_dataset = load_dataset(
    "allenai/c4",
    data_files="en/c4-train.00001-of-01024.json.gz",
    split="train",
).select(range(1024))["text"]
# Out:
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/allenai/c4/resolve/main/README.md "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/datasets/allenai/c4/1588ec454efa1a09f29cd18ddd04fe05fc8653a2/README.md "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/allenai/c4/resolve/1588ec454efa1a09f29cd18ddd04fe05fc8653a2/c4.py "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/allenai/c4/allenai/c4.py "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/allenai/c4/resolve/1588ec454efa1a09f29cd18ddd04fe05fc8653a2/.huggingface.yaml "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/allenai/c4/resolve/1588ec454efa1a09f29cd18ddd04fe05fc8653a2/dataset_infos.json "HTTP/1.1 404 Not Found"

# %%
quant_config = QuantizeConfig(
    bits=4, 
    group_size=128, 
)
# Out:
# INFO  QuantizeConfig: offload_to_disk_path auto set to temporary dir `/tmp/gptqmodel_p3d_nlur`

# %%
model = GPTQModel.load(model_id, quant_config)
# Out:
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/unsloth/Llama-3.2-1B-Instruct/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/unsloth/Llama-3.2-1B-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unsloth/Llama-3.2-1B-Instruct/5a8abab4a5d6f164389b1079fb721cfab8d7126c/config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unsloth/Llama-3.2-1B-Instruct/5a8abab4a5d6f164389b1079fb721cfab8d7126c/config.json "HTTP/1.1 200 OK"
# config.json:   0%|          | 0.00/894 [00:00<?, ?B/s]
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/unsloth/Llama-3.2-1B-Instruct/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/unsloth/Llama-3.2-1B-Instruct/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/unsloth/Llama-3.2-1B-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unsloth/Llama-3.2-1B-Instruct/5a8abab4a5d6f164389b1079fb721cfab8d7126c/config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/unsloth/Llama-3.2-1B-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unsloth/Llama-3.2-1B-Instruct/5a8abab4a5d6f164389b1079fb721cfab8d7126c/config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/unsloth/Llama-3.2-1B-Instruct/revision/main "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/unsloth/Llama-3.2-1B-Instruct/tree/5a8abab4a5d6f164389b1079fb721cfab8d7126c?recursive=true&expand=false "HTTP/1.1 200 OK"
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/unsloth/Llama-3.2-1B-Instruct/resolve/5a8abab4a5d6f164389b1079fb721cfab8d7126c/README.md "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unsloth/Llama-3.2-1B-Instruct/5a8abab4a5d6f164389b1079fb721cfab8d7126c/README.md "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/unsloth/Llama-3.2-1B-Instruct/resolve/5a8abab4a5d6f164389b1079fb721cfab8d7126c/chat_template.jinja "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/unsloth/Llama-3.2-1B-Instruct/resolve/5a8abab4a5d6f164389b1079fb721cfab8d7126c/special_tokens_map.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/unsloth/Llama-3.2-1B-Instruct/resolve/5a8abab4a5d6f164389b1079fb721cfab8d7126c/generation_config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/unsloth/Llama-3.2-1B-Instruct/resolve/5a8abab4a5d6f164389b1079fb721cfab8d7126c/.gitattributes "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/unsloth/Llama-3.2-1B-Instruct/resolve/5a8abab4a5d6f164389b1079fb721cfab8d7126c/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unsloth/Llama-3.2-1B-Instruct/5a8abab4a5d6f164389b1079fb721cfab8d7126c/README.md "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unsloth/Llama-3.2-1B-Instruct/5a8abab4a5d6f164389b1079fb721cfab8d7126c/chat_template.jinja "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unsloth/Llama-3.2-1B-Instruct/5a8abab4a5d6f164389b1079fb721cfab8d7126c/special_tokens_map.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unsloth/Llama-3.2-1B-Instruct/5a8abab4a5d6f164389b1079fb721cfab8d7126c/generation_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unsloth/Llama-3.2-1B-Instruct/5a8abab4a5d6f164389b1079fb721cfab8d7126c/.gitattributes "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unsloth/Llama-3.2-1B-Instruct/5a8abab4a5d6f164389b1079fb721cfab8d7126c/tokenizer_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unsloth/Llama-3.2-1B-Instruct/5a8abab4a5d6f164389b1079fb721cfab8d7126c/chat_template.jinja "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unsloth/Llama-3.2-1B-Instruct/5a8abab4a5d6f164389b1079fb721cfab8d7126c/special_tokens_map.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unsloth/Llama-3.2-1B-Instruct/5a8abab4a5d6f164389b1079fb721cfab8d7126c/generation_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unsloth/Llama-3.2-1B-Instruct/5a8abab4a5d6f164389b1079fb721cfab8d7126c/tokenizer_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/unsloth/Llama-3.2-1B-Instruct/5a8abab4a5d6f164389b1079fb721cfab8d7126c/.gitattributes "HTTP/1.1 200 OK"
# INFO  Loader: Auto dtype (native bfloat16): `torch.bfloat16`
# INFO:tokenicer.tokenicer:Tokenicer: Auto fixed pad_token_id=128004 (token='<|finetune_right_pad_id|>').
# INFO  Estimated Quantization BPW (bits per weight): 4.2875 bpw, based on [bits: 4, group_size: 128]
# INFO  Loader: using checkpoint-backed lazy turtle source for `/home/ankitanand/.cache/huggingface/hub/models--unsloth--Llama-3.2-1B-Instruct/snapshots/5a8abab4a5d6f164389b1079fb721cfab8d7126c`
# INFO:tokenicer.tokenicer:Tokenicer: Auto fixed pad_token_id=128004 (token='<|finetune_right_pad_id|>').
# INFO  Model: Loaded `generation_config`: GenerationConfig {
#   "bos_token_id": 128000,
#   "eos_token_id": 128009,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "pad_token_id": 128004,
#   "use_cache": true
# }
#
# INFO  Model: Auto-fixed `generation_config` mismatch between model and `generation_config.json`.
# INFO  Model: Updated `generation_config`: GenerationConfig {
#   "bos_token_id": 128000,
#   "do_sample": true,
#   "eos_token_id": [
#     128001,
#     128008,
#     128009
#   ],
#   "max_length": 131072,
#   "pad_token_id": 128004,
#   "temperature": 0.6,
#   "top_p": 0.9
# }
#
# INFO  Kernel: loaded -> `[]`

# %%
model.quantize(caliberation_dataset, batch_size=1)
# Out:
# INFO  Packing Kernel: selected: `TorchLinear`
# INFO  Packing Kernel: selected: `TorchLinear`
# INFO  Calibration: Sort in descending order by length
# INFO  Calibration: Total padded tokens: 0
# INFO  Calibration: Total non-padded tokens: 454766
# INFO  Calibration: Total tokens: 454766
# INFO  Disk subsystem write throughput detected at 1148.3 MB/s.
# INFO  ModuleLooper: capturing layer inputs from 1024 calibration batches
# INFO  Offloading base modules to disk...
# INFO  | region      | count | last_s | avg_s | total_s | pct    | source      |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Capture ... | 1     | 3.660  | 3.660 | 3.660   | 100.0% | cache_in... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 0 | ... | 20... | bf16... | ... | ... | ... | ... | 1. | n |    |
# INFO  +-----+---+-----+-------+---------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 0 | ... | 20... | bf1... | ... | ... | ... | 0. | 1... | n |    |
# INFO  +-----+---+-----+-------+--------+-----+-----+-----+----+------+---+----+
# INFO  | ... | 0 | ... | 20... | bf1... | ... | ... | ... | 0. | 1... | n |    |
# INFO  +-----+---+-----+-------+--------+-----+-----+-----+----+------+---+----+
# INFO  | ... | 0 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 0 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 0 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 0 | ... | 8192... | bf1... | 0. | ... | 0. | 1. | 8... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | Pre-quan... | 4     | 8.811  | 3.475 | 13.901  | 43.0%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Forward ... | 7168  | 0.002  | 0.001 | 8.215   | 25.4%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Process ... | 7     | 1.024  | 0.704 | 4.927   | 15.2%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Capture ... | 1     | 3.660  | 3.660 | 3.660   | 11.3%  | cache_in... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Post-qua... | 1     | 1.642  | 1.642 | 1.642   | 5.1%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  Extension load requested for `pack_block_cpu`: pack_block_cpu
# INFO  Extension load requested for `pack_block_cpu`: pack_block_cpu
# INFO  pack_block_cpu: compiling torch.ops JIT extension in `/home/ankitanand/.cache/gptqmodel/torch_extensions/pack_block_cpu/f4171f5cc4553596`.
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 1 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 1 | ... | 20... | bf1... | ... | ... | ... | 0. | 1... | n |    |
# INFO  +-----+---+-----+-------+--------+-----+-----+-----+----+------+---+----+
# INFO  | ... | 1 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 1 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 0... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 1 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 1 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  pack_block_cpu: torch.ops JIT extension ready in 13s (estimated ~31s, -18s).
# INFO  Extension load finished successfully: pack_block_cpu
# INFO  Extension load finished successfully: pack_block_cpu
# INFO  Format: Converting GPTQ v2 to v1
# INFO  | ... | 1 | ... | 8192... | bf1... | 0. | ... | 0. | 1. | 8... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | Submodu... | 7     | 14.169 | 14.041 | 98.289  | 38.8%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 7     | 13.400 | 9.553  | 66.869  | 26.4%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Pre-qua... | 8     | 8.876  | 3.439  | 27.513  | 10.9%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 7     | 0.165  | 3.910  | 27.368  | 10.8%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Forward... | 14336 | 0.002  | 0.001  | 16.551  | 6.5%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Process... | 14    | 1.029  | 0.693  | 9.697   | 3.8%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Capture... | 1     | 3.660  | 3.660  | 3.660   | 1.4%   | cache_in... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Post-qu... | 2     | 1.565  | 1.603  | 3.207   | 1.3%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 7     | 0.010  | 0.021  | 0.145   | 0.1%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 2 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 2 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 2 | ... | 20... | bf1... | ... | ... | ... | 0. | 1... | n |    |
# INFO  +-----+---+-----+-------+--------+-----+-----+-----+----+------+---+----+
# INFO  | ... | 2 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 0... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 2 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 2 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 2 | ... | 8192... | bf1... | 0. | ... | 0. | 1. | 8... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | Submodu... | 14    | 0.877  | 7.436  | 104.110 | 36.1%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 14    | 0.018  | 4.787  | 67.022  | 23.2%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Pre-qua... | 12    | 8.706  | 3.410  | 40.920  | 14.2%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 14    | 0.090  | 2.020  | 28.277  | 9.8%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Forward... | 21504 | 0.002  | 0.001  | 24.865  | 8.6%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Process... | 21    | 1.113  | 0.697  | 14.634  | 5.1%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Post-qu... | 3     | 1.537  | 1.581  | 4.743   | 1.6%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Capture... | 1     | 3.660  | 3.660  | 3.660   | 1.3%   | cache_in... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 14    | 0.003  | 0.013  | 0.176   | 0.1%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 3 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 3 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 3 | ... | 20... | bf1... | ... | ... | ... | 0. | 1... | n |    |
# INFO  +-----+---+-----+-------+--------+-----+-----+-----+----+------+---+----+
# INFO  | ... | 3 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 0... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 3 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 3 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 3 | ... | 8192... | bf1... | 0. | ... | 0. | 1. | 8... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | Submodu... | 21    | 1.109  | 5.296  | 111.214 | 33.9%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 21    | 0.855  | 3.271  | 68.693  | 21.0%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Pre-qua... | 16    | 8.865  | 3.408  | 54.523  | 16.6%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Forward... | 28672 | 0.002  | 0.001  | 33.208  | 10.1%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 21    | 0.106  | 1.441  | 30.264  | 9.2%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Process... | 28    | 1.023  | 0.705  | 19.732  | 6.0%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Post-qu... | 4     | 1.552  | 1.574  | 6.295   | 1.9%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Capture... | 1     | 3.660  | 3.660  | 3.660   | 1.1%   | cache_in... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 21    | 0.006  | 0.013  | 0.278   | 0.1%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 4 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 4 | ... | 20... | bf1... | ... | ... | ... | 0. | 1... | n |    |
# INFO  +-----+---+-----+-------+--------+-----+-----+-----+----+------+---+----+
# INFO  | ... | 4 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 4 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 0... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 4 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 4 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 4 | ... | 8192... | bf1... | 0. | ... | 0. | 1. | 8... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | Submodu... | 28    | 0.970  | 4.186  | 117.212 | 32.1%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 28    | 0.762  | 2.491  | 69.743  | 19.1%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Pre-qua... | 20    | 8.754  | 3.402  | 68.036  | 18.7%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Forward... | 35840 | 0.002  | 0.001  | 41.598  | 11.4%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 28    | 0.124  | 1.144  | 32.029  | 8.8%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Process... | 35    | 1.086  | 0.694  | 24.280  | 6.7%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Post-qu... | 5     | 1.544  | 1.568  | 7.839   | 2.1%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Capture... | 1     | 3.660  | 3.660  | 3.660   | 1.0%   | cache_in... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 28    | 0.007  | 0.013  | 0.377   | 0.1%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 5 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 5 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 5 | ... | 20... | bf1... | ... | ... | ... | 0. | 1... | n |    |
# INFO  +-----+---+-----+-------+--------+-----+-----+-----+----+------+---+----+
# INFO  | ... | 5 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 0... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 5 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 5 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 5 | ... | 8192... | bf1... | 0. | ... | 0. | 1. | 8... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | Submodu... | 35    | 0.971  | 3.533  | 123.665 | 30.8%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Pre-qua... | 24    | 8.840  | 3.399  | 81.565  | 20.3%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 35    | 0.345  | 2.008  | 70.271  | 17.5%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Forward... | 43008 | 0.002  | 0.001  | 49.905  | 12.4%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 35    | 0.075  | 0.967  | 33.829  | 8.4%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Process... | 42    | 1.004  | 0.691  | 29.013  | 7.2%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Post-qu... | 6     | 1.554  | 1.566  | 9.393   | 2.3%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Capture... | 1     | 3.660  | 3.660  | 3.660   | 0.9%   | cache_in... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 35    | 0.006  | 0.014  | 0.490   | 0.1%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 6 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 6 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 6 | ... | 20... | bf1... | ... | ... | ... | 0. | 1... | n |    |
# INFO  +-----+---+-----+-------+--------+-----+-----+-----+----+------+---+----+
# INFO  | ... | 6 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 0... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 6 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 6 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 6 | ... | 8192... | bf1... | 0. | ... | 0. | 1. | 8... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | Submodu... | 42    | 1.091  | 3.105  | 130.400 | 29.7%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Pre-qua... | 28    | 8.726  | 3.395  | 95.047  | 21.6%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 42    | 0.188  | 1.694  | 71.146  | 16.2%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Forward... | 50176 | 0.002  | 0.001  | 58.214  | 13.2%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 42    | 0.129  | 0.853  | 35.814  | 8.1%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Process... | 49    | 1.037  | 0.691  | 33.846  | 7.7%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Post-qu... | 7     | 1.541  | 1.562  | 10.935  | 2.5%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Capture... | 1     | 3.660  | 3.660  | 3.660   | 0.8%   | cache_in... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 42    | 0.073  | 0.015  | 0.627   | 0.1%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 7 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 7 | ... | 20... | bf1... | ... | ... | ... | 0. | 1... | n |    |
# INFO  +-----+---+-----+-------+--------+-----+-----+-----+----+------+---+----+
# INFO  | ... | 7 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 7 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 0... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 7 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 7 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 7 | ... | 8192... | bf1... | 0. | ... | 0. | 1. | 8... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | Submodu... | 49    | 1.015  | 2.797  | 137.073 | 28.7%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Pre-qua... | 32    | 8.870  | 3.395  | 108.629 | 22.8%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 49    | 0.389  | 1.462  | 71.646  | 15.0%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Forward... | 57344 | 0.002  | 0.001  | 66.527  | 13.9%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Process... | 56    | 1.027  | 0.691  | 38.693  | 8.1%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 49    | 0.072  | 0.771  | 37.757  | 7.9%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Post-qu... | 8     | 1.610  | 1.568  | 12.545  | 2.6%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Capture... | 1     | 3.660  | 3.660  | 3.660   | 0.8%   | cache_in... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 49    | 0.010  | 0.015  | 0.736   | 0.2%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 8 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 8 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 8 | ... | 20... | bf1... | ... | ... | ... | 0. | 1... | n |    |
# INFO  +-----+---+-----+-------+--------+-----+-----+-----+----+------+---+----+
# INFO  | ... | 8 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 0... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 8 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 8 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 8 | ... | 8192... | bf1... | 0. | ... | 0. | 0. | 8... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | Submodu... | 56    | 0.981  | 2.559  | 143.313 | 27.8%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Pre-qua... | 36    | 8.914  | 3.397  | 122.299 | 23.8%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Forward... | 64512 | 0.002  | 0.001  | 75.038  | 14.6%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 56    | 0.051  | 1.302  | 72.914  | 14.2%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Process... | 63    | 1.002  | 0.695  | 43.791  | 8.5%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 56    | 0.104  | 0.696  | 39.000  | 7.6%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Post-qu... | 9     | 1.604  | 1.572  | 14.149  | 2.7%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Capture... | 1     | 3.660  | 3.660  | 3.660   | 0.7%   | cache_in... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 56    | 0.003  | 0.014  | 0.762   | 0.1%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 9 | ... | 20... | bf16... | ... | ... | ... | ... | 1. | n |    |
# INFO  +-----+---+-----+-------+---------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 9 | ... | 20... | bf1... | ... | ... | ... | 0. | 1... | n |    |
# INFO  +-----+---+-----+-------+--------+-----+-----+-----+----+------+---+----+
# INFO  | ... | 9 | ... | 20... | bf1... | ... | ... | ... | 0. | 1... | n |    |
# INFO  +-----+---+-----+-------+--------+-----+-----+-----+----+------+---+----+
# INFO  | ... | 9 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 0... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 9 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 9 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 9 | ... | 8192... | bf1... | 0. | ... | 0. | 1. | 8... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | Submodu... | 63    | 1.058  | 2.382  | 150.085 | 27.2%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Pre-qua... | 40    | 8.820  | 3.396  | 135.845 | 24.6%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Forward... | 71680 | 0.002  | 0.001  | 83.392  | 15.1%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 63    | 0.097  | 1.168  | 73.583  | 13.3%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Process... | 70    | 1.011  | 0.693  | 48.543  | 8.8%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 63    | 0.067  | 0.645  | 40.630  | 7.4%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Post-qu... | 10    | 1.583  | 1.573  | 15.732  | 2.8%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Capture... | 1     | 3.660  | 3.660  | 3.660   | 0.7%   | cache_in... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 63    | 0.003  | 0.014  | 0.872   | 0.2%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 1 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 10 | ... | 204... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+----+-----+--------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 10 | ... | 20... | bf1... | ... | ... | ... | ... | 1. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 10 | ... | 20... | bf1... | ... | ... | ... | ... | 0. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 10 | ... | 20... | bf1... | ... | ... | ... | ... | 2. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 10 | ... | 20... | bf1... | ... | ... | ... | ... | 2. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 10 | ... | 81... | bf1... | ... | ... | ... | ... | 8. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | Submodu... | 70    | 0.904  | 2.225  | 155.746 | 26.5%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Pre-qua... | 44    | 8.901  | 3.400  | 149.617 | 25.4%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Forward... | 78848 | 0.002  | 0.001  | 91.937  | 15.6%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 70    | 0.503  | 1.062  | 74.337  | 12.6%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Process... | 77    | 1.020  | 0.689  | 53.069  | 9.0%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 70    | 0.101  | 0.595  | 41.677  | 7.1%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Post-qu... | 11    | 1.653  | 1.580  | 17.385  | 3.0%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Capture... | 1     | 3.660  | 3.660  | 3.660   | 0.6%   | cache_in... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 70    | 0.007  | 0.014  | 0.962   | 0.2%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 1 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 11 | ... | 204... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+----+-----+--------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 11 | ... | 20... | bf1... | ... | ... | ... | ... | 1. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 11 | ... | 20... | bf1... | ... | ... | ... | ... | 0. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 11 | ... | 20... | bf1... | ... | ... | ... | ... | 2. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 11 | ... | 20... | bf1... | ... | ... | ... | ... | 2. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 11 | ... | 81... | bf1... | ... | ... | ... | ... | 9. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | Pre-qua... | 48    | 9.075  | 3.406  | 163.484 | 26.1%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Submodu... | 77    | 0.970  | 2.100  | 161.717 | 25.9%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Forward... | 86016 | 0.003  | 0.001  | 100.603 | 16.1%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 77    | 0.332  | 0.972  | 74.873  | 12.0%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Process... | 84    | 1.368  | 0.688  | 57.753  | 9.2%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 77    | 0.130  | 0.565  | 43.469  | 6.9%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Post-qu... | 12    | 1.585  | 1.581  | 18.970  | 3.0%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Capture... | 1     | 3.660  | 3.660  | 3.660   | 0.6%   | cache_in... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 77    | 0.007  | 0.014  | 1.050   | 0.2%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 1 | ... | 20... | bf16... | ... | ... | ... | ... | 1. | n |    |
# INFO  +-----+---+-----+-------+---------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 12 | ... | 204... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+----+-----+--------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 12 | ... | 204... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+----+-----+--------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 12 | ... | 20... | bf1... | ... | ... | ... | ... | 0. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 12 | ... | 20... | bf1... | ... | ... | ... | ... | 2. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 12 | ... | 20... | bf1... | ... | ... | ... | ... | 2. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 12 | ... | 81... | bf1... | ... | ... | ... | ... | 8. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | Pre-qua... | 52    | 8.789  | 3.404  | 177.011 | 26.9%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Submodu... | 84    | 0.688  | 1.978  | 166.172 | 25.2%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Forward... | 93184 | 0.002  | 0.001  | 108.968 | 16.5%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 84    | 0.136  | 0.896  | 75.281  | 11.4%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Process... | 91    | 1.003  | 0.678  | 61.702  | 9.4%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 84    | 0.070  | 0.532  | 44.672  | 6.8%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Post-qu... | 13    | 1.534  | 1.577  | 20.504  | 3.1%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Capture... | 1     | 3.660  | 3.660  | 3.660   | 0.6%   | cache_in... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Finaliz... | 84    | 0.007  | 0.013  | 1.127   | 0.2%   | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 1 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 13 | ... | 204... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+----+-----+--------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 13 | ... | 20... | bf1... | ... | ... | ... | ... | 1. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 13 | ... | 20... | bf1... | ... | ... | ... | ... | 0. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 13 | ... | 20... | bf1... | ... | ... | ... | ... | 2. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 13 | ... | 20... | bf1... | ... | ... | ... | ... | 2. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 13 | ... | 81... | bf1... | ... | ... | ... | ... | 8. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | Pre-qua... | 56    | 8.799  | 3.403  | 190.542 | 27.4%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Submodu... | 91    | 1.040  | 1.899  | 172.795 | 24.8%  | model.la... |
# INFO  +------------+-------+--------+--------+---------+--------+-------------+
# INFO  | Forward... | 100352 | 0.002  | 0.001  | 117.311 | 16.9%  | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Finaliz... | 91     | 0.039  | 0.843  | 76.718  | 11.0%  | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Process... | 98     | 1.004  | 0.670  | 65.657  | 9.4%   | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Finaliz... | 91     | 0.124  | 0.505  | 45.944  | 6.6%   | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Post-qu... | 14     | 1.615  | 1.580  | 22.119  | 3.2%   | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Capture... | 1      | 3.660  | 3.660  | 3.660   | 0.5%   | cache_i... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Finaliz... | 91     | 0.007  | 0.014  | 1.240   | 0.2%   | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 1 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 14 | ... | 204... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+----+-----+--------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 14 | ... | 20... | bf1... | ... | ... | ... | ... | 1. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 14 | ... | 20... | bf1... | ... | ... | ... | ... | 0. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 14 | ... | 20... | bf1... | ... | ... | ... | ... | 2. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 14 | ... | 20... | bf1... | ... | ... | ... | ... | 2. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 14 | ... | 81... | bf1... | ... | ... | ... | ... | 8. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | Pre-qua... | 60     | 8.782  | 3.402  | 204.093 | 27.8%  | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Submodu... | 98     | 1.080  | 1.834  | 179.722 | 24.5%  | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Forward... | 107520 | 0.002  | 0.001  | 125.658 | 17.1%  | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Finaliz... | 98     | 0.613  | 0.792  | 77.568  | 10.6%  | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Process... | 105    | 1.011  | 0.671  | 70.506  | 9.6%   | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Finaliz... | 98     | 0.099  | 0.481  | 47.163  | 6.4%   | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Post-qu... | 15     | 1.610  | 1.582  | 23.729  | 3.2%   | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Capture... | 1      | 3.660  | 3.660  | 3.660   | 0.5%   | cache_i... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Finaliz... | 98     | 0.007  | 0.014  | 1.378   | 0.2%   | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 1 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 15 | ... | 20... | bf1... | ... | ... | ... | ... | 1. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 15 | ... | 204... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+----+-----+--------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 15 | ... | 20... | bf1... | ... | ... | ... | ... | 0. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 15 | ... | 20... | bf1... | ... | ... | ... | ... | 2. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 15 | ... | 20... | bf1... | ... | ... | ... | ... | 2. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 15 | ... | 81... | bf1... | ... | ... | ... | ... | 8. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | Pre-qua... | 64     | 8.817  | 3.401  | 217.652 | 28.3%  | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Submodu... | 105    | 1.096  | 1.779  | 186.816 | 24.3%  | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Forward... | 114688 | 0.002  | 0.001  | 134.012 | 17.4%  | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Finaliz... | 105    | 0.914  | 0.749  | 78.632  | 10.2%  | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Process... | 112    | 1.024  | 0.674  | 75.492  | 9.8%   | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Finaliz... | 105    | 0.097  | 0.463  | 48.665  | 6.3%   | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Post-qu... | 15     | 1.610  | 1.582  | 23.729  | 3.1%   | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Capture... | 1      | 3.660  | 3.660  | 3.660   | 0.5%   | cache_i... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Finaliz... | 105    | 0.007  | 0.014  | 1.518   | 0.2%   | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  {'process': 'gptq', 'layer': 0, 'module': 'self_attn.q_proj', 'feat: in, out': '2048, 2048', 'dtype: size': 'bf16: 8.3MB', 'loss': '0.0000038726', 'samples': '454766', 'damp': '0.05000', 'time': '0.715', 'fwd_time': '1.767', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 0, 'module': 'self_attn.k_proj', 'feat: in, out': '2048, 512', 'dtype: size': 'bf16: 2.1MB', 'loss': '0.0000018339', 'samples': '454766', 'damp': '0.05000', 'time': '0.776', 'fwd_time': '1.767', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 0, 'module': 'self_attn.v_proj', 'feat: in, out': '2048, 512', 'dtype: size': 'bf16: 2.1MB', 'loss': '0.0000000593', 'samples': '454766', 'damp': '0.05000', 'time': '0.764', 'fwd_time': '1.767', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 0, 'module': 'self_attn.o_proj', 'feat: in, out': '2048, 2048', 'dtype: size': 'bf16: 8.3MB', 'loss': '0.0000000043', 'samples': '454766', 'damp': '0.05000', 'time': '0.250', 'fwd_time': '1.071', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 0, 'module': 'mlp.gate_proj', 'feat: in, out': '2048, 8192', 'dtype: size': 'bf16: 33.0MB', 'loss': '0.0000035847', 'samples': '454766', 'damp': '0.05000', 'time': '0.672', 'fwd_time': '2.252', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 0, 'module': 'mlp.up_proj', 'feat: in, out': '2048, 8192', 'dtype: size': 'bf16: 33.0MB', 'loss': '0.0000028006', 'samples': '454766', 'damp': '0.05000', 'time': '0.690', 'fwd_time': '2.252', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 0, 'module': 'mlp.down_proj', 'feat: in, out': '8192, 2048', 'dtype: size': 'bf16: 33.0MB', 'loss': '0.0000000250', 'samples': '454766', 'damp': '0.05000', 'time': '1.021', 'fwd_time': '8.811', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 1, 'module': 'self_attn.k_proj', 'feat: in, out': '2048, 512', 'dtype: size': 'bf16: 2.1MB', 'loss': '0.0000031872', 'samples': '454766', 'damp': '0.05000', 'time': '0.840', 'fwd_time': '1.649', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 1, 'module': 'self_attn.v_proj', 'feat: in, out': '2048, 512', 'dtype: size': 'bf16: 2.1MB', 'loss': '0.0000001996', 'samples': '454766', 'damp': '0.05000', 'time': '0.846', 'fwd_time': '1.649', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 1, 'module': 'self_attn.q_proj', 'feat: in, out': '2048, 2048', 'dtype: size': 'bf16: 8.3MB', 'loss': '0.0000063542', 'samples': '454766', 'damp': '0.05000', 'time': '0.852', 'fwd_time': '1.649', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 1, 'module': 'self_attn.o_proj', 'feat: in, out': '2048, 2048', 'dtype: size': 'bf16: 8.3MB', 'loss': '0.0000000108', 'samples': '454766', 'damp': '0.05000', 'time': '0.206', 'fwd_time': '0.950', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 1, 'module': 'mlp.up_proj', 'feat: in, out': '2048, 8192', 'dtype: size': 'bf16: 33.0MB', 'loss': '0.0000042211', 'samples': '454766', 'damp': '0.05000', 'time': '0.483', 'fwd_time': '2.137', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 1, 'module': 'mlp.gate_proj', 'feat: in, out': '2048, 8192', 'dtype: size': 'bf16: 33.0MB', 'loss': '0.0000057308', 'samples': '454766', 'damp': '0.05000', 'time': '0.487', 'fwd_time': '2.137', '(v)ram': 'n/a'}
# ...
#    'damp': '0.05000',
#    'time': '0.585',
#    'fwd_time': '2.133',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 7,
#    'module': 'mlp.up_proj',
#    'feat: in, out': '2048, 8192',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000077002',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.589',
#    'fwd_time': '2.133',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 7,
#    'module': 'mlp.down_proj',
#    'feat: in, out': '8192, 2048',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000001685',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '1.022',
#    'fwd_time': '8.870',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 8,
#    'module': 'self_attn.v_proj',
#    'feat: in, out': '2048, 512',
#    'dtype: size': 'bf16: 2.1MB',
#    'loss': '0.0000006408',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.815',
#    'fwd_time': '1.648',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 8,
#    'module': 'self_attn.q_proj',
#    'feat: in, out': '2048, 2048',
#    'dtype: size': 'bf16: 8.3MB',
#    'loss': '0.0000107813',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.833',
#    'fwd_time': '1.648',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 8,
#    'module': 'self_attn.k_proj',
#    'feat: in, out': '2048, 512',
#    'dtype: size': 'bf16: 2.1MB',
#    'loss': '0.0000065187',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.840',
#    'fwd_time': '1.648',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 8,
#    'module': 'self_attn.o_proj',
#    'feat: in, out': '2048, 2048',
#    'dtype: size': 'bf16: 8.3MB',
#    'loss': '0.0000001210',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.205',
#    'fwd_time': '0.961',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 8,
#    'module': 'mlp.up_proj',
#    'feat: in, out': '2048, 8192',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000090256',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.684',
#    'fwd_time': '2.147',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 8,
#    'module': 'mlp.gate_proj',
#    'feat: in, out': '2048, 8192',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000146721',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.687',
#    'fwd_time': '2.147',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 8,
#    'module': 'mlp.down_proj',
#    'feat: in, out': '8192, 2048',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000002296',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.999',
#    'fwd_time': '8.914',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 9,
#    'module': 'self_attn.q_proj',
#    'feat: in, out': '2048, 2048',
#    'dtype: size': 'bf16: 8.3MB',
#    'loss': '0.0000114834',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.742',
#    'fwd_time': '1.652',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 9,
#    'module': 'self_attn.k_proj',
#    'feat: in, out': '2048, 512',
#    'dtype: size': 'bf16: 2.1MB',
#    'loss': '0.0000046291',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.757',
#    'fwd_time': '1.652',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 9,
#    'module': 'self_attn.v_proj',
#    'feat: in, out': '2048, 512',
#    'dtype: size': 'bf16: 2.1MB',
#    'loss': '0.0000007518',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.760',
#    'fwd_time': '1.652',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 9,
#    'module': 'self_attn.o_proj',
#    'feat: in, out': '2048, 2048',
#    'dtype: size': 'bf16: 8.3MB',
#    'loss': '0.0000001366',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.204',
#    'fwd_time': '0.950',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 9,
#    'module': 'mlp.gate_proj',
#    'feat: in, out': '2048, 8192',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000158009',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.624',
#    'fwd_time': '2.123',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 9,
#    'module': 'mlp.up_proj',
#    'feat: in, out': '2048, 8192',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000095531',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.630',
#    'fwd_time': '2.123',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 9,
#    'module': 'mlp.down_proj',
#    'feat: in, out': '8192, 2048',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000002841',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '1.007',
#    'fwd_time': '8.820',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 10,
#    'module': 'self_attn.v_proj',
#    'feat: in, out': '2048, 512',
#    'dtype: size': 'bf16: 2.1MB',
#    'loss': '0.0000010622',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.756',
#    'fwd_time': '1.703',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 10,
#    'module': 'self_attn.k_proj',
#    'feat: in, out': '2048, 512',
#    'dtype: size': 'bf16: 2.1MB',
#    'loss': '0.0000057751',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.772',
#    'fwd_time': '1.703',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 10,
#    'module': 'self_attn.q_proj',
#    'feat: in, out': '2048, 2048',
#    'dtype: size': 'bf16: 8.3MB',
#    'loss': '0.0000129879',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.777',
#    'fwd_time': '1.703',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 10,
#    'module': 'self_attn.o_proj',
#    'feat: in, out': '2048, 2048',
#    'dtype: size': 'bf16: 8.3MB',
#    'loss': '0.0000000970',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.206',
#    'fwd_time': '0.992',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 10,
#    'module': 'mlp.up_proj',
#    'feat: in, out': '2048, 8192',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000110513',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.486',
#    'fwd_time': '2.177',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 10,
#    'module': 'mlp.gate_proj',
#    'feat: in, out': '2048, 8192',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000173995',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.489',
#    'fwd_time': '2.177',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 10,
#    'module': 'mlp.down_proj',
#    'feat: in, out': '8192, 2048',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000003487',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '1.016',
#    'fwd_time': '8.901',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 11,
#    'module': 'self_attn.k_proj',
#    'feat: in, out': '2048, 512',
#    'dtype: size': 'bf16: 2.1MB',
#    'loss': '0.0000067790',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.688',
#    'fwd_time': '1.698',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 11,
#    'module': 'self_attn.v_proj',
#    'feat: in, out': '2048, 512',
#    'dtype: size': 'bf16: 2.1MB',
#    'loss': '0.0000009472',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.696',
#    'fwd_time': '1.698',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 11,
#    'module': 'self_attn.q_proj',
#    'feat: in, out': '2048, 2048',
#    'dtype: size': 'bf16: 8.3MB',
#    'loss': '0.0000124012',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.700',
#    'fwd_time': '1.698',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 11,
#    'module': 'self_attn.o_proj',
#    'feat: in, out': '2048, 2048',
#    'dtype: size': 'bf16: 8.3MB',
#    'loss': '0.0000000731',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.204',
#    'fwd_time': '0.953',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 11,
#    'module': 'mlp.up_proj',
#    'feat: in, out': '2048, 8192',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000118051',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.501',
#    'fwd_time': '2.141',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 11,
#    'module': 'mlp.gate_proj',
#    'feat: in, out': '2048, 8192',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000182552',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.506',
#    'fwd_time': '2.141',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 11,
#    'module': 'mlp.down_proj',
#    'feat: in, out': '8192, 2048',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000003860',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '1.364',
#    'fwd_time': '9.075',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 12,
#    'module': 'self_attn.q_proj',
#    'feat: in, out': '2048, 2048',
#    'dtype: size': 'bf16: 8.3MB',
#    'loss': '0.0000125111',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.576',
#    'fwd_time': '1.671',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 12,
#    'module': 'self_attn.v_proj',
#    'feat: in, out': '2048, 512',
#    'dtype: size': 'bf16: 2.1MB',
#    'loss': '0.0000009933',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.575',
#    'fwd_time': '1.671',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 12,
#    'module': 'self_attn.k_proj',
#    'feat: in, out': '2048, 512',
#    'dtype: size': 'bf16: 2.1MB',
#    'loss': '0.0000066345',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.585',
#    'fwd_time': '1.671',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 12,
#    'module': 'self_attn.o_proj',
#    'feat: in, out': '2048, 2048',
#    'dtype: size': 'bf16: 8.3MB',
#    'loss': '0.0000000769',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.201',
#    'fwd_time': '0.951',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 12,
#    'module': 'mlp.gate_proj',
#    'feat: in, out': '2048, 8192',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000179894',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.487',
#    'fwd_time': '2.116',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 12,
#    'module': 'mlp.up_proj',
#    'feat: in, out': '2048, 8192',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000121184',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.494',
#    'fwd_time': '2.116',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 12,
#    'module': 'mlp.down_proj',
#    'feat: in, out': '8192, 2048',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000004348',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.999',
#    'fwd_time': '8.789',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 13,
#    'module': 'self_attn.k_proj',
#    'feat: in, out': '2048, 512',
#    'dtype: size': 'bf16: 2.1MB',
#    'loss': '0.0000066704',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.574',
#    'fwd_time': '1.655',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 13,
#    'module': 'self_attn.v_proj',
#    'feat: in, out': '2048, 512',
#    'dtype: size': 'bf16: 2.1MB',
#    'loss': '0.0000017106',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.579',
#    'fwd_time': '1.655',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 13,
#    'module': 'self_attn.q_proj',
#    'feat: in, out': '2048, 2048',
#    'dtype: size': 'bf16: 8.3MB',
#    'loss': '0.0000142986',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.579',
#    'fwd_time': '1.655',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 13,
#    'module': 'self_attn.o_proj',
#    'feat: in, out': '2048, 2048',
#    'dtype: size': 'bf16: 8.3MB',
#    'loss': '0.0000001032',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.205',
#    'fwd_time': '0.950',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 13,
#    'module': 'mlp.up_proj',
#    'feat: in, out': '2048, 8192',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000140965',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.480',
#    'fwd_time': '2.128',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 13,
#    'module': 'mlp.gate_proj',
#    'feat: in, out': '2048, 8192',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000194857',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.482',
#    'fwd_time': '2.128',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 13,
#    'module': 'mlp.down_proj',
#    'feat: in, out': '8192, 2048',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000006395',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '1.000',
#    'fwd_time': '8.799',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 14,
#    'module': 'self_attn.k_proj',
#    'feat: in, out': '2048, 512',
#    'dtype: size': 'bf16: 2.1MB',
#    'loss': '0.0000070012',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.823',
#    'fwd_time': '1.660',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 14,
#    'module': 'self_attn.v_proj',
#    'feat: in, out': '2048, 512',
#    'dtype: size': 'bf16: 2.1MB',
#    'loss': '0.0000035810',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.831',
#    'fwd_time': '1.660',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 14,
#    'module': 'self_attn.q_proj',
#    'feat: in, out': '2048, 2048',
#    'dtype: size': 'bf16: 8.3MB',
#    'loss': '0.0000139711',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.846',
#    'fwd_time': '1.660',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 14,
#    'module': 'self_attn.o_proj',
#    'feat: in, out': '2048, 2048',
#    'dtype: size': 'bf16: 8.3MB',
#    'loss': '0.0000002490',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.201',
#    'fwd_time': '0.959',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 14,
#    'module': 'mlp.up_proj',
#    'feat: in, out': '2048, 8192',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000159140',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.552',
#    'fwd_time': '2.151',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 14,
#    'module': 'mlp.gate_proj',
#    'feat: in, out': '2048, 8192',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000234714',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.561',
#    'fwd_time': '2.151',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 14,
#    'module': 'mlp.down_proj',
#    'feat: in, out': '8192, 2048',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000009002',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '1.007',
#    'fwd_time': '8.782',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 15,
#    'module': 'self_attn.v_proj',
#    'feat: in, out': '2048, 512',
#    'dtype: size': 'bf16: 2.1MB',
#    'loss': '0.0000036949',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.781',
#    'fwd_time': '1.639',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 15,
#    'module': 'self_attn.q_proj',
#    'feat: in, out': '2048, 2048',
#    'dtype: size': 'bf16: 8.3MB',
#    'loss': '0.0000128856',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.790',
#    'fwd_time': '1.639',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 15,
#    'module': 'self_attn.k_proj',
#    'feat: in, out': '2048, 512',
#    'dtype: size': 'bf16: 2.1MB',
#    'loss': '0.0000076672',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.800',
#    'fwd_time': '1.639',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 15,
#    'module': 'self_attn.o_proj',
#    'feat: in, out': '2048, 2048',
#    'dtype: size': 'bf16: 8.3MB',
#    'loss': '0.0000009990',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.207',
#    'fwd_time': '0.952',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 15,
#    'module': 'mlp.gate_proj',
#    'feat: in, out': '2048, 8192',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000262429',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.678',
#    'fwd_time': '2.151',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 15,
#    'module': 'mlp.up_proj',
#    'feat: in, out': '2048, 8192',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000197593',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '0.684',
#    'fwd_time': '2.151',
#    '(v)ram': 'n/a'},
#   {'process': 'gptq',
#    'layer': 15,
#    'module': 'mlp.down_proj',
#    'feat: in, out': '8192, 2048',
#    'dtype: size': 'bf16: 33.0MB',
#    'loss': '0.0000029965',
#    'samples': '454766',
#    'damp': '0.05000',
#    'time': '1.019',
#    'fwd_time': '8.817',
#    '(v)ram': 'n/a'}]}

# %%
model.save(quant_path)
# Out:
# Writing model shards: 0it [00:00, ?it/s]
# INFO  Saved Quantize Config:
# {
#   "bits": 4,
#   "group_size": 128,
#   "desc_act": false,
#   "lm_head": false,
#   "method": "gptq",
#   "quant_method": "gptq",
#   "format": "gptq",
#   "checkpoint_format": "gptq",
#   "pack_dtype": "int32",
#   "meta": {
#     "quantizer": [
#       "gptqmodel:7.3.2"
#     ],
#     "uri": "https://github.com/modelcloud/gptqmodel",
#     "damp_percent": 0.05,
#     "damp_auto_increment": 0.01,
#     "static_groups": false,
#     "true_sequential": true,
#     "mse": 0.0,
#     "gptaq": null,
#     "foem": null,
#     "act_group_aware": true,
#     "fallback": {
#       "strategy": "rtn",
#       "threshold": "0.5%",
#       "smooth": null
#     },
#     "offload_to_disk": true,
#     "offload_to_disk_path": "/tmp/gptqmodel_p3d_nlur",
#     "pack_impl": "cpu",
#     "gc_mode": "interval",
#     "wait_for_submodule_finalizers": false,
#     "auto_forward_data_parallel": true,
#     "dense_vram_strategy": "exclusive",
#     "dense_vram_strategy_devices": null,
#     "moe_vram_strategy": "exclusive",
#     "moe_vram_strategy_devices": null,
#     "mock_quantization": false,
#     "hessian": {
#       "chunk_size": null,
#       "chunk_bytes": null,
#       "staging_dtype": "float32"
#     }
#   },
#   "sym": true
# }
# Files in directory:
# config.json
# quantize_config.json
# generation_config.json
# quant_log.csv
# Content of saved `generation_config.json`:
# {
#     "bos_token_id": 128000,
#     "do_sample": true,
#     "eos_token_id": [
#         128001,
#         128008,
#         128009
#     ],
#     "max_length": 131072,
#     "pad_token_id": 128004,
#     "temperature": 0.6,
#     "top_p": 0.9,
#     "transformers_version": "5.14.1"
# }
# Content of saved `config.json`:
# {
#     "architectures": [
#         "LlamaForCausalLM"
#     ],
#     "attention_bias": false,
#     "attention_dropout": 0.0,
#     "bos_token_id": 128000,
#     "dtype": "bfloat16",
#     "eos_token_id": 128009,
#     "head_dim": 64,
#     "hidden_act": "silu",
#     "hidden_size": 2048,
#     "initializer_range": 0.02,
#     "intermediate_size": 8192,
#     "max_position_embeddings": 131072,
#     "mlp_bias": false,
#     "model_type": "llama",
#     "num_attention_heads": 32,
#     "num_hidden_layers": 16,
#     "num_key_value_heads": 8,
#     "pad_token_id": 128004,
#     "pretraining_tp": 1,
#     "quantization_config": {
#         "bits": 4,
#         "checkpoint_format": "gptq",
#         "desc_act": false,
#         "format": "gptq",
#         "group_size": 128,
#         "lm_head": false,
#         "meta": {
#             "act_group_aware": true,
#             "auto_forward_data_parallel": true,
#             "damp_auto_increment": 0.01,
#             "damp_percent": 0.05,
#             "dense_vram_strategy": "exclusive",
#             "dense_vram_strategy_devices": null,
#             "fallback": {
#                 "smooth": null,
#                 "strategy": "rtn",
#                 "threshold": "0.5%"
#             },
#             "foem": null,
#             "gc_mode": "interval",
#             "gptaq": null,
#             "hessian": {
#                 "chunk_bytes": null,
#                 "chunk_size": null,
#                 "staging_dtype": "float32"
#             },
#             "mock_quantization": false,
#             "moe_vram_strategy": "exclusive",
#             "moe_vram_strategy_devices": null,
#             "mse": 0.0,
#             "offload_to_disk": true,
#             "offload_to_disk_path": "/tmp/gptqmodel_p3d_nlur",
#             "pack_impl": "cpu",
#             "quantizer": [
#                 "gptqmodel:7.3.2"
#             ],
#             "static_groups": false,
#             "true_sequential": true,
#             "uri": "https://github.com/modelcloud/gptqmodel",
#             "wait_for_submodule_finalizers": false
#         },
#         "method": "gptq",
#         "pack_dtype": "int32",
#         "quant_method": "gptq",
#         "sym": true
#     },
#     "rms_norm_eps": 1e-05,
#     "rope_parameters": {
#         "factor": 32.0,
#         "high_freq_factor": 4.0,
#         "low_freq_factor": 1.0,
#         "original_max_position_embeddings": 8192,
#         "rope_theta": 500000.0,
#         "rope_type": "llama3"
#     },
#     "tie_word_embeddings": true,
#     "transformers_version": "5.14.1",
#     "unsloth_fixed": true,
#     "use_cache": false,
#     "vocab_size": 128256
# }
# INFO  Module: Re-tied embedding weights on shell model after lazy sync
# INFO  Module: Total direct tensors materialized from lazy checkpoint source: 1
# INFO  Pre-Quantized model size: 2357.14MB, 2.30GB
# INFO  Quantized model size: 984.55MB, 0.96GB
# INFO  Size difference: 1372.59MB, 1.34GB - 58.23%
# INFO  | Pre-qua... | 64     | 8.817  | 3.401  | 217.652 | 28.2%  | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Submodu... | 112    | 0.152  | 1.674  | 187.439 | 24.3%  | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Forward... | 114688 | 0.002  | 0.001  | 134.012 | 17.4%  | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Finaliz... | 112    | 0.053  | 0.703  | 78.790  | 10.2%  | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Process... | 112    | 1.024  | 0.674  | 75.492  | 9.8%   | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Finaliz... | 112    | 0.081  | 0.436  | 48.885  | 6.3%   | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Post-qu... | 15     | 1.610  | 1.582  | 23.729  | 3.1%   | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Capture... | 1      | 3.660  | 3.660  | 3.660   | 0.5%   | cache_i... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Finaliz... | 112    | 0.009  | 0.015  | 1.702   | 0.2%   | model.l... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Model save | 1      | 0.835  | 0.835  | 0.835   | 0.1%   | /home/a... |
# INFO  +------------+--------+--------+--------+---------+--------+------------+
# INFO  | Process... | 1      | 0.000  | 0.000  | 0.000   | 0.0%   | gptq       |
# INFO  +------------+--------+--------+--------+---------+--------+------------+

# %%
from huggingface_hub import upload_folder, create_repo 

repo_id = "ankitanand9/Llama-3.2-1B-Instruct-gptqmodel-4bit"
create_repo(repo_id, repo_type="model", private=True, exist_ok=True)

upload_folder(
    repo_id="ankitanand9/Llama-3.2-1B-Instruct-gptqmodel-4bit",
    folder_path="./Llama-3.2-1B-Instruct-gptqmodel-4bit",
    commit_message="Upload GPTQ quantized LLaMA-3.2-1B model"
)
# Out:
# INFO:httpx:HTTP Request: POST https://huggingface.co/api/repos/create "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://huggingface.co/api/models/ankitanand9/Llama-3.2-1B-Instruct-gptqmodel-4bit/preupload/main "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://huggingface.co/api/models/ankitanand9/Llama-3.2-1B-Instruct-gptqmodel-4bit/commit/main "HTTP/1.1 200 OK"
# CommitInfo(commit_url='https://huggingface.co/ankitanand9/Llama-3.2-1B-Instruct-gptqmodel-4bit/commit/a436b800d5ba57f711c4ece685dc3ca25d751cc1', commit_message='Upload GPTQ quantized LLaMA-3.2-1B model', commit_description='', oid='a436b800d5ba57f711c4ece685dc3ca25d751cc1', pr_url=None, repo_url=RepoUrl('https://huggingface.co/ankitanand9/Llama-3.2-1B-Instruct-gptqmodel-4bit', endpoint='https://huggingface.co', repo_type='model', repo_id='ankitanand9/Llama-3.2-1B-Instruct-gptqmodel-4bit'), pr_revision=None, pr_num=None)

# %%
# test post-quant inference
model = GPTQModel.load(quant_path)
result = model.generate("Hello, how are you?")[0] # tokens
print(model.tokenizer.decode(result)) # string output
# Out:
# from_quantized: adapter: None
# INFO  Loader: Auto dtype (native bfloat16): `torch.bfloat16`
# INFO  Estimated Quantization BPW (bits per weight): 4.2875 bpw, based on [bits: 4, group_size: 128]
# INFO:tokenicer.tokenicer:Tokenicer: Auto fixed pad_token_id=128004 (token='<|finetune_right_pad_id|>').
# INFO  The layer model.embed_tokens is not quantized.
# INFO  Kernel: Auto-selection: adding candidate `MarlinLinear`
# INFO  Kernel: Auto-selection: adding candidate `ExllamaV2Linear`
# INFO  Kernel: Auto-selection: adding candidate `TritonV2Linear`
# INFO  Kernel: Auto-selection: adding candidate `TorchLinear`
# INFO  Kernel: candidates -> `[MarlinLinear, ExllamaV2Linear, TritonV2Linear, TorchLinear]`
# INFO  Kernel: per-module selections -> `[MarlinLinear=112]`
# INFO  Kernel: selected -> `MarlinLinear`.
# INFO  Loader: device = DEVICE.CUDA
# INFO  Loader: Built map across 1 GPU(s), 20 entries. First 8: [('model.embed_tokens', 'cuda:0'), ('model.layers.0', 'cuda:0'), ('model.layers.1', 'cuda:0'), ('model.layers.2', 'cuda:0'), ('model.layers.3', 'cuda:0'), ('model.layers.4', 'cuda:0'), ('model.layers.5', 'cuda:0'), ('model.layers.6', 'cuda:0')]
# INFO  Loader: device_map = {'model.embed_tokens': 'cuda:0', 'model.layers.0': 'cuda:0', 'model.layers.1': 'cuda:0', 'model.layers.2': 'cuda:0', 'model.layers.3': 'cuda:0', 'model.layers.4': 'cuda:0', 'model.layers.5': 'cuda:0', 'model.layers.6': 'cuda:0', 'model.layers.7': 'cuda:0', 'model.layers.8': 'cuda:0', 'model.layers.9': 'cuda:0', 'model.layers.10': 'cuda:0', 'model.layers.11': 'cuda:0', 'model.layers.12': 'cuda:0', 'model.layers.13': 'cuda:0', 'model.layers.14': 'cuda:0', 'model.layers.15': 'cuda:0', 'lm_head': 'cuda:0', 'model.norm': 'cuda:0', 'model.rotary_emb': 'cuda:0'}
# WARNING:accelerate.utils.modeling:The model weights are not tied. Please use the `tie_weights` method before using the `infer_auto_device` function.
# INFO  Kernel: Auto-selection: adding candidate `MarlinLinear`
# INFO  Kernel: selected -> `MarlinLinear`.
# INFO  gc.collect() reclaimed 3 objects in 0.219s
# INFO:tokenicer.tokenicer:Tokenicer: Auto fixed pad_token_id=128004 (token='<|finetune_right_pad_id|>').
# INFO  Model: Loaded `generation_config`: GenerationConfig {
#   "bos_token_id": 128000,
#   "eos_token_id": 128009,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "pad_token_id": 128004,
#   "use_cache": false
# }
#
# INFO  Model: Auto-fixed `generation_config` mismatch between model and `generation_config.json`.
# INFO  Model: Updated `generation_config`: GenerationConfig {
#   "bos_token_id": 128000,
#   "do_sample": true,
#   "eos_token_id": [
#     128001,
#     128008,
#     128009
#   ],
#   "max_length": 131072,
#   "pad_token_id": 128004,
#   "temperature": 0.6,
#   "top_p": 0.9
# }
#
# INFO  Kernel: loaded -> `[MarlinLinear]`
# <|begin_of_text|>Hello, how are you? I'm just a language model, I don't have feelings or emotions like humans do, but I'm here to help you with any questions or topics you'd like to discuss.
#
# What's on your mind today? Do you have a specific question or topic you'd like to chat about? I'm all ears (or rather, all text).<|eot_id|>

# %%
from datasets import load_dataset
from gptqmodel import GPTQModel, QuantizeConfig
import torch

def calculate_avg_ppl(model, tokenizer, texts, max_length=512, batch_size=8):
    """Compute average perplexity over a list of plain text strings."""
    from gptqmodel.utils.perplexity import Perplexity

    ppl = Perplexity(
        model=model,
        tokenizer=tokenizer,
        dataset_path=None,
        split=None,
        text_column=None,
    )
    # Pass list of text strings
    return ppl.calculate_from_texts(texts, max_length, batch_size)

def load_normal_model(model_id):
    return GPTQModel.load(model_id, quantize_config=None)

def load_quant_model(quant_path, device):
    return GPTQModel.load(quant_path, device=device)

def main():
    model_id = "unsloth/Llama-3.2-1B-Instruct"
    quant_path = "Llama-3.2-1B-Instruct-gptq-4bit"
    # Load calibration / eval dataset texts
    calibration_texts = load_dataset(
        "allenai/c4",
        data_files="en/c4-train.00001-of-01024.json.gz",
        split="train"
    ).select(range(1024))["text"]

    # Subset for evaluation
    eval_texts = calibration_texts[:100]

    # Try loading quantized model if exists
    try:
        device = "cuda:0" if torch.cuda.is_available() else "cpu"
        quant_model = load_quant_model(quant_path, device=device)
        quant_exists = True
    except Exception as e:
        print("Quantized model not found or failed to load:", e)
        quant_exists = False

    # Load normal (unquantized) model
    normal_model = load_normal_model(model_id)

    # If quantized model doesn't exist, create it
    if not quant_exists:
        quant_config = QuantizeConfig(bits=4, group_size=128)
        print("Quantizing model now...")
        model = GPTQModel.load(model_id, quant_config)
        model.quantize(calibration_texts, batch_size=1)
        model.save(quant_path)
        quant_model = load_quant_model(quant_path, device=device)

    # Evaluate normal model
    print("Evaluating normal model...")
    ppl_normal = calculate_avg_ppl(normal_model, normal_model.tokenizer, eval_texts)
    print("Normal model avg PPL:", ppl_normal)

    # Evaluate quantized model
    print("Evaluating quantized model...")
    ppl_quant = calculate_avg_ppl(quant_model, quant_model.tokenizer, eval_texts)
    print("Quantized model avg PPL:", ppl_quant)

if __name__ == "__main__":
    main()
# Out:
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/allenai/c4/resolve/main/README.md "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/datasets/allenai/c4/1588ec454efa1a09f29cd18ddd04fe05fc8653a2/README.md "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/allenai/c4/resolve/1588ec454efa1a09f29cd18ddd04fe05fc8653a2/c4.py "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/allenai/c4/allenai/c4.py "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/allenai/c4/resolve/1588ec454efa1a09f29cd18ddd04fe05fc8653a2/.huggingface.yaml "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/allenai/c4/resolve/1588ec454efa1a09f29cd18ddd04fe05fc8653a2/dataset_infos.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/Llama-3.2-1B-Instruct-gptq-4bit/resolve/main/config.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/unsloth/Llama-3.2-1B-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unsloth/Llama-3.2-1B-Instruct/5a8abab4a5d6f164389b1079fb721cfab8d7126c/config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/unsloth/Llama-3.2-1B-Instruct/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/unsloth/Llama-3.2-1B-Instruct/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# Quantized model not found or failed to load: Llama-3.2-1B-Instruct-gptq-4bit is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/unsloth/Llama-3.2-1B-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unsloth/Llama-3.2-1B-Instruct/5a8abab4a5d6f164389b1079fb721cfab8d7126c/config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/unsloth/Llama-3.2-1B-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unsloth/Llama-3.2-1B-Instruct/5a8abab4a5d6f164389b1079fb721cfab8d7126c/config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/unsloth/Llama-3.2-1B-Instruct/revision/main "HTTP/1.1 200 OK"
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# INFO  Loader: Auto dtype (native bfloat16): `torch.bfloat16`
# INFO:tokenicer.tokenicer:Tokenicer: Auto fixed pad_token_id=128004 (token='<|finetune_right_pad_id|>').
# Loading weights:   0%|          | 0/146 [00:00<?, ?it/s]
# INFO:tokenicer.tokenicer:Tokenicer: Auto fixed pad_token_id=128004 (token='<|finetune_right_pad_id|>').
# INFO  Model: Loaded `generation_config`: GenerationConfig {
#   "bos_token_id": 128000,
#   "do_sample": true,
#   "eos_token_id": [
#     128001,
#     128008,
#     128009
#   ],
#   "max_length": 131072,
#   "pad_token_id": 128004,
#   "temperature": 0.6,
#   "top_p": 0.9
# }
#
# INFO  Kernel: loaded -> `[]`
# INFO  QuantizeConfig: offload_to_disk_path auto set to temporary dir `/tmp/gptqmodel_ark4ak32`
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/unsloth/Llama-3.2-1B-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unsloth/Llama-3.2-1B-Instruct/5a8abab4a5d6f164389b1079fb721cfab8d7126c/config.json "HTTP/1.1 200 OK"
# Quantizing model now...
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/unsloth/Llama-3.2-1B-Instruct/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/unsloth/Llama-3.2-1B-Instruct/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/unsloth/Llama-3.2-1B-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unsloth/Llama-3.2-1B-Instruct/5a8abab4a5d6f164389b1079fb721cfab8d7126c/config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/unsloth/Llama-3.2-1B-Instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/unsloth/Llama-3.2-1B-Instruct/5a8abab4a5d6f164389b1079fb721cfab8d7126c/config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/unsloth/Llama-3.2-1B-Instruct/revision/main "HTTP/1.1 200 OK"
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# INFO  Loader: Auto dtype (native bfloat16): `torch.bfloat16`
# INFO:tokenicer.tokenicer:Tokenicer: Auto fixed pad_token_id=128004 (token='<|finetune_right_pad_id|>').
# INFO  Estimated Quantization BPW (bits per weight): 4.2875 bpw, based on [bits: 4, group_size: 128]
# INFO  Loader: using checkpoint-backed lazy turtle source for `/home/ankitanand/.cache/huggingface/hub/models--unsloth--Llama-3.2-1B-Instruct/snapshots/5a8abab4a5d6f164389b1079fb721cfab8d7126c`
# INFO:tokenicer.tokenicer:Tokenicer: Auto fixed pad_token_id=128004 (token='<|finetune_right_pad_id|>').
# INFO  Model: Loaded `generation_config`: GenerationConfig {
#   "bos_token_id": 128000,
#   "eos_token_id": 128009,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "pad_token_id": 128004,
#   "use_cache": true
# }
#
# INFO  Model: Auto-fixed `generation_config` mismatch between model and `generation_config.json`.
# INFO  Model: Updated `generation_config`: GenerationConfig {
#   "bos_token_id": 128000,
#   "do_sample": true,
#   "eos_token_id": [
#     128001,
#     128008,
#     128009
#   ],
#   "max_length": 131072,
#   "pad_token_id": 128004,
#   "temperature": 0.6,
#   "top_p": 0.9
# }
#
# INFO  Kernel: loaded -> `[]`
# INFO  Packing Kernel: selected: `TorchLinear`
# INFO  Packing Kernel: selected: `TorchLinear`
# INFO  Calibration: Sort in descending order by length
# INFO  Calibration: Total padded tokens: 0
# INFO  Calibration: Total non-padded tokens: 454766
# INFO  Calibration: Total tokens: 454766
# INFO  Disk subsystem write throughput detected at 1148.3 MB/s.
# INFO  ModuleLooper: capturing layer inputs from 1024 calibration batches
# INFO  Offloading base modules to disk...
# INFO  +------------+-------+--------+-------+---------+--------+---------+
# INFO  | region     | count | last_s | avg_s | total_s | pct    | source  |
# INFO  +------------+-------+--------+-------+---------+--------+---------+
# INFO  | Capture ... | 1     | 3.314  | 3.314 | 3.314   | 100.0% | cache_in... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 0 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 0 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 0 | ... | 20... | bf1... | ... | ... | ... | 0. | 1... | n |    |
# INFO  +-----+---+-----+-------+--------+-----+-----+-----+----+------+---+----+
# INFO  | ... | 0 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 0 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 0 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 0 | ... | 8192... | bf1... | 0. | ... | 0. | 1. | 8... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | Pre-quan... | 4     | 8.760  | 3.428 | 13.712  | 44.0%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Forward ... | 7168  | 0.002  | 0.001 | 8.285   | 26.6%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Process ... | 7     | 1.025  | 0.611 | 4.279   | 13.7%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Capture ... | 1     | 3.314  | 3.314 | 3.314   | 10.6%  | cache_in... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Post-qua... | 1     | 1.597  | 1.597 | 1.597   | 5.1%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 1 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 1 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 1 | ... | 20... | bf1... | ... | ... | ... | 0. | 1... | n |    |
# INFO  +-----+---+-----+-------+--------+-----+-----+-----+----+------+---+----+
# INFO  | ... | 1 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 0... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 1 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 1 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 1 | ... | 8192... | bf1... | 0. | ... | 0. | 1. | 8... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | Pre-quan... | 8     | 8.692  | 3.387 | 27.094  | 40.8%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Forward ... | 14336 | 0.002  | 0.001 | 16.573  | 25.0%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Process ... | 14    | 1.005  | 0.670 | 9.380   | 14.1%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Submodul... | 7     | 0.831  | 0.729 | 5.103   | 7.7%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Capture ... | 1     | 3.314  | 3.314 | 3.314   | 5.0%   | cache_in... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Post-qua... | 2     | 1.598  | 1.597 | 3.195   | 4.8%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 7     | 0.097  | 0.139 | 0.974   | 1.5%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 7     | 0.088  | 0.087 | 0.612   | 0.9%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 7     | 0.008  | 0.013 | 0.092   | 0.1%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 2 | ... | 20... | bf16... | ... | ... | ... | ... | 1. | n |    |
# INFO  +-----+---+-----+-------+---------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 2 | ... | 20... | bf1... | ... | ... | ... | 0. | 1... | n |    |
# INFO  +-----+---+-----+-------+--------+-----+-----+-----+----+------+---+----+
# INFO  | ... | 2 | ... | 20... | bf1... | ... | ... | ... | 0. | 1... | n |    |
# INFO  +-----+---+-----+-------+--------+-----+-----+-----+----+------+---+----+
# INFO  | ... | 2 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 0... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 2 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 2 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 2 | ... | 8192... | bf1... | 0. | ... | 0. | 1. | 8... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | Pre-quan... | 12    | 8.924  | 3.391 | 40.693  | 39.1%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Forward ... | 21504 | 0.002  | 0.001 | 25.100  | 24.1%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Process ... | 21    | 1.027  | 0.688 | 14.452  | 13.9%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Submodul... | 14    | 1.102  | 0.858 | 12.012  | 11.5%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Post-qua... | 3     | 1.569  | 1.588 | 4.764   | 4.6%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Capture ... | 1     | 3.314  | 3.314 | 3.314   | 3.2%   | cache_in... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 14    | 0.132  | 0.192 | 2.685   | 2.6%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 14    | 0.065  | 0.069 | 0.964   | 0.9%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 14    | 0.003  | 0.010 | 0.140   | 0.1%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 3 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 3 | ... | 20... | bf1... | ... | ... | ... | 0. | 1... | n |    |
# INFO  +-----+---+-----+-------+--------+-----+-----+-----+----+------+---+----+
# INFO  | ... | 3 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 3 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 0... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 3 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 3 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 3 | ... | 8192... | bf1... | 0. | ... | 0. | 1. | 8... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | Pre-quan... | 16    | 8.755  | 3.383 | 54.129  | 38.6%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Forward ... | 28672 | 0.002  | 0.001 | 33.482  | 23.9%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Process ... | 28    | 1.009  | 0.699 | 19.580  | 13.9%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Submodul... | 21    | 0.925  | 0.855 | 17.960  | 12.8%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Post-qua... | 4     | 1.565  | 1.582 | 6.329   | 4.5%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 21    | 0.073  | 0.196 | 4.109   | 2.9%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Capture ... | 1     | 3.314  | 3.314 | 3.314   | 2.4%   | cache_in... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 21    | 0.067  | 0.059 | 1.245   | 0.9%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 21    | 0.007  | 0.010 | 0.217   | 0.2%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 4 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 4 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 4 | ... | 20... | bf1... | ... | ... | ... | 0. | 1... | n |    |
# INFO  +-----+---+-----+-------+--------+-----+-----+-----+----+------+---+----+
# INFO  | ... | 4 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 0... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 4 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 4 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 4 | ... | 8192... | bf1... | 0. | ... | 0. | 0. | 8... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | Pre-quan... | 20    | 8.722  | 3.376 | 67.523  | 38.1%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Forward ... | 35840 | 0.002  | 0.001 | 41.828  | 23.6%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Process ... | 35    | 1.000  | 0.703 | 24.610  | 13.9%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Submodul... | 28    | 1.018  | 0.877 | 24.570  | 13.9%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Post-qua... | 5     | 1.566  | 1.579 | 7.894   | 4.5%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 28    | 0.078  | 0.204 | 5.721   | 3.2%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Capture ... | 1     | 3.314  | 3.314 | 3.314   | 1.9%   | cache_in... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 28    | 0.139  | 0.057 | 1.583   | 0.9%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 28    | 0.003  | 0.009 | 0.256   | 0.1%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 5 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 5 | ... | 20... | bf1... | ... | ... | ... | 0. | 1... | n |    |
# INFO  +-----+---+-----+-------+--------+-----+-----+-----+----+------+---+----+
# INFO  | ... | 5 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 5 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 0... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 5 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 5 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 5 | ... | 8192... | bf1... | 0. | ... | 0. | 1. | 8... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | Pre-quan... | 24    | 8.786  | 3.376 | 81.026  | 37.8%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Forward ... | 43008 | 0.002  | 0.001 | 50.229  | 23.4%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Submodul... | 35    | 0.990  | 0.879 | 30.749  | 14.3%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Process ... | 42    | 1.020  | 0.707 | 29.707  | 13.9%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Post-qua... | 6     | 1.569  | 1.577 | 9.463   | 4.4%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 35    | 0.117  | 0.213 | 7.460   | 3.5%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Capture ... | 1     | 3.314  | 3.314 | 3.314   | 1.5%   | cache_in... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 35    | 0.062  | 0.059 | 2.058   | 1.0%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 35    | 0.074  | 0.010 | 0.364   | 0.2%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 6 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 6 | ... | 20... | bf1... | ... | ... | ... | 0. | 1... | n |    |
# INFO  +-----+---+-----+-------+--------+-----+-----+-----+----+------+---+----+
# INFO  | ... | 6 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 6 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 0... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 6 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 6 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 6 | ... | 8192... | bf1... | 0. | ... | 0. | 1. | 8... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | Pre-quan... | 28    | 8.716  | 3.373 | 94.449  | 37.5%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Forward ... | 50176 | 0.002  | 0.001 | 58.506  | 23.2%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Submodul... | 42    | 1.063  | 0.896 | 37.633  | 14.9%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Process ... | 49    | 1.021  | 0.689 | 33.749  | 13.4%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Post-qua... | 7     | 1.565  | 1.576 | 11.029  | 4.4%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 42    | 0.105  | 0.225 | 9.454   | 3.8%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 42    | 0.068  | 0.080 | 3.372   | 1.3%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Capture ... | 1     | 3.314  | 3.314 | 3.314   | 1.3%   | cache_in... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 42    | 0.007  | 0.012 | 0.504   | 0.2%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 7 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 7 | ... | 20... | bf1... | ... | ... | ... | 0. | 1... | n |    |
# INFO  +-----+---+-----+-------+--------+-----+-----+-----+----+------+---+----+
# INFO  | ... | 7 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 7 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 0... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 7 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 7 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 7 | ... | 8192... | bf1... | 0. | ... | 0. | 1. | 8... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | Pre-quan... | 32    | 8.714  | 3.371 | 107.863 | 37.3%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Forward ... | 57344 | 0.002  | 0.001 | 66.790  | 23.1%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Submodul... | 49    | 1.043  | 0.901 | 44.140  | 15.3%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Process ... | 56    | 1.023  | 0.690 | 38.630  | 13.4%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Post-qua... | 8     | 1.617  | 1.581 | 12.646  | 4.4%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 49    | 0.128  | 0.230 | 11.280  | 3.9%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 49    | 0.168  | 0.077 | 3.772   | 1.3%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Capture ... | 1     | 3.314  | 3.314 | 3.314   | 1.1%   | cache_in... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 49    | 0.008  | 0.012 | 0.602   | 0.2%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 8 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 8 | ... | 20... | bf1... | ... | ... | ... | 0. | 1... | n |    |
# INFO  +-----+---+-----+-------+--------+-----+-----+-----+----+------+---+----+
# INFO  | ... | 8 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 8 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 0... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 8 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 8 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 8 | ... | 8192... | bf1... | 0. | ... | 0. | 1. | 8... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | Pre-quan... | 36    | 8.754  | 3.371 | 121.338 | 37.4%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Forward ... | 64512 | 0.002  | 0.001 | 75.146  | 23.2%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Submodul... | 56    | 0.941  | 0.892 | 49.975  | 15.4%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Process ... | 63    | 1.017  | 0.676 | 42.565  | 13.1%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Post-qua... | 9     | 1.575  | 1.580 | 14.221  | 4.4%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 56    | 0.109  | 0.232 | 12.966  | 4.0%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 56    | 0.343  | 0.079 | 4.421   | 1.4%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Capture ... | 1     | 3.314  | 3.314 | 3.314   | 1.0%   | cache_in... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 56    | 0.003  | 0.011 | 0.633   | 0.2%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 9 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 9 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 9 | ... | 20... | bf1... | ... | ... | ... | 0. | 1... | n |    |
# INFO  +-----+---+-----+-------+--------+-----+-----+-----+----+------+---+----+
# INFO  | ... | 9 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 0... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 9 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 9 | ... | 2048... | bf1... | 0. | ... | 0. | 0. | 2... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 9 | ... | 8192... | bf1... | 0. | ... | 0. | 1. | 8... | n |    |
# INFO  +-----+---+-----+---------+--------+----+-----+----+----+------+---+----+
# INFO  | Pre-quan... | 40    | 8.757  | 3.370 | 134.792 | 37.1%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Forward ... | 71680 | 0.002  | 0.001 | 83.493  | 23.0%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Submodul... | 63    | 1.083  | 0.904 | 56.926  | 15.7%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Process ... | 70    | 1.019  | 0.683 | 47.808  | 13.1%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Post-qua... | 10    | 1.577  | 1.580 | 15.798  | 4.3%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 63    | 0.107  | 0.226 | 14.219  | 3.9%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 63    | 0.062  | 0.104 | 6.533   | 1.8%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Capture ... | 1     | 3.314  | 3.314 | 3.314   | 0.9%   | cache_in... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 63    | 0.002  | 0.012 | 0.745   | 0.2%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 1 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 10 | ... | 20... | bf1... | ... | ... | ... | ... | 1. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 10 | ... | 204... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+----+-----+--------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 10 | ... | 20... | bf1... | ... | ... | ... | ... | 0. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 10 | ... | 20... | bf1... | ... | ... | ... | ... | 2. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 10 | ... | 20... | bf1... | ... | ... | ... | ... | 2. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 10 | ... | 81... | bf1... | ... | ... | ... | ... | 8. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | Pre-quan... | 44    | 8.752  | 3.370 | 148.274 | 36.9%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Forward ... | 78848 | 0.002  | 0.001 | 91.865  | 22.9%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Submodul... | 70    | 1.044  | 0.908 | 63.591  | 15.8%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Process ... | 77    | 1.022  | 0.688 | 52.950  | 13.2%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Post-qua... | 11    | 1.619  | 1.583 | 17.417  | 4.3%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 70    | 0.099  | 0.231 | 16.176  | 4.0%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 70    | 0.066  | 0.107 | 7.507   | 1.9%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Capture ... | 1     | 3.314  | 3.314 | 3.314   | 0.8%   | cache_in... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 70    | 0.007  | 0.012 | 0.822   | 0.2%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 1 | ... | 20... | bf16... | ... | ... | ... | ... | 1. | n |    |
# INFO  +-----+---+-----+-------+---------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 11 | ... | 204... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+----+-----+--------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 11 | ... | 204... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+----+-----+--------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 11 | ... | 20... | bf1... | ... | ... | ... | ... | 0. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 11 | ... | 20... | bf1... | ... | ... | ... | ... | 2. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 11 | ... | 20... | bf1... | ... | ... | ... | ... | 2. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 11 | ... | 81... | bf1... | ... | ... | ... | ... | 8. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | Pre-quan... | 48    | 8.822  | 3.371 | 161.787 | 36.8%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Forward ... | 86016 | 0.002  | 0.001 | 100.305 | 22.8%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Submodul... | 77    | 1.049  | 0.917 | 70.627  | 16.1%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Process ... | 84    | 1.010  | 0.689 | 57.844  | 13.1%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Post-qua... | 12    | 1.574  | 1.583 | 18.991  | 4.3%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 77    | 0.034  | 0.235 | 18.131  | 4.1%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 77    | 0.060  | 0.105 | 8.098   | 1.8%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Capture ... | 1     | 3.314  | 3.314 | 3.314   | 0.8%   | cache_in... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 77    | 0.006  | 0.011 | 0.855   | 0.2%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 1 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 12 | ... | 204... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+----+-----+--------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 12 | ... | 20... | bf1... | ... | ... | ... | ... | 1. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 12 | ... | 20... | bf1... | ... | ... | ... | ... | 0. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 12 | ... | 20... | bf1... | ... | ... | ... | ... | 2. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 12 | ... | 20... | bf1... | ... | ... | ... | ... | 2. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 12 | ... | 81... | bf1... | ... | ... | ... | ... | 8. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | Pre-quan... | 52    | 8.764  | 3.375 | 175.477 | 36.9%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Forward ... | 93184 | 0.002  | 0.001 | 108.851 | 22.9%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Submodul... | 84    | 0.731  | 0.897 | 75.338  | 15.8%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Process ... | 91    | 1.012  | 0.694 | 63.176  | 13.3%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Post-qua... | 13    | 1.575  | 1.582 | 20.565  | 4.3%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 84    | 0.075  | 0.231 | 19.390  | 4.1%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 84    | 0.132  | 0.099 | 8.333   | 1.8%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Capture ... | 1     | 3.314  | 3.314 | 3.314   | 0.7%   | cache_in... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Finalize... | 84    | 0.008  | 0.011 | 0.946   | 0.2%   | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 1 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 13 | ... | 20... | bf1... | ... | ... | ... | ... | 1. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 13 | ... | 204... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+----+-----+--------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 13 | ... | 20... | bf1... | ... | ... | ... | ... | 0. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 13 | ... | 20... | bf1... | ... | ... | ... | ... | 2. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 13 | ... | 20... | bf1... | ... | ... | ... | ... | 2. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 13 | ... | 81... | bf1... | ... | ... | ... | ... | 8. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | Pre-quan... | 56    | 8.758  | 3.374 | 188.936 | 36.7%  | model.la... |
# INFO  +-------------+-------+--------+-------+---------+--------+-------------+
# INFO  | Forward... | 100352 | 0.002  | 0.001 | 117.199 | 22.8%  | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Submodu... | 91     | 1.116  | 0.906 | 82.486  | 16.0%  | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Process... | 98     | 1.022  | 0.694 | 67.980  | 13.2%  | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Post-qu... | 14     | 1.576  | 1.582 | 22.142  | 4.3%   | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Finaliz... | 91     | 0.107  | 0.235 | 21.371  | 4.2%   | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Finaliz... | 91     | 0.880  | 0.107 | 9.699   | 1.9%   | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Capture... | 1      | 3.314  | 3.314 | 3.314   | 0.6%   | cache_in... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Finaliz... | 91     | 0.008  | 0.012 | 1.105   | 0.2%   | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# INFO  +------+-----+-----+-------+------+---+------+---+---+------+----+------+
# INFO  | ... | 1 | ... | 204... | bf16... | ... | ... | ... | 0. | 1. | n |    |
# INFO  +-----+---+-----+--------+---------+-----+-----+-----+----+----+---+----+
# INFO  | ... | 14 | ... | 204... | bf1... | 0. | ... | 0. | 0. | 1... | n |    |
# INFO  +-----+----+-----+--------+--------+----+-----+----+----+------+---+----+
# INFO  | ... | 14 | ... | 20... | bf1... | ... | ... | ... | ... | 1. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 14 | ... | 20... | bf1... | ... | ... | ... | ... | 0. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 14 | ... | 20... | bf1... | ... | ... | ... | ... | 2. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 14 | ... | 20... | bf1... | ... | ... | ... | ... | 2. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | ... | 14 | ... | 81... | bf1... | ... | ... | ... | ... | 8. | n |    |
# INFO  +-----+----+-----+-------+--------+-----+-----+-----+-----+----+---+----+
# INFO  | Pre-qua... | 60     | 8.733  | 3.373 | 202.379 | 36.6%  | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Forward... | 107520 | 0.002  | 0.001 | 125.493 | 22.7%  | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Submodu... | 98     | 1.060  | 0.911 | 89.247  | 16.2%  | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Process... | 105    | 1.014  | 0.696 | 73.047  | 13.2%  | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Post-qu... | 15     | 1.577  | 1.581 | 23.719  | 4.3%   | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Finaliz... | 98     | 0.106  | 0.239 | 23.407  | 4.2%   | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Finaliz... | 98     | 0.146  | 0.110 | 10.803  | 2.0%   | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Capture... | 1      | 3.314  | 3.314 | 3.314   | 0.6%   | cache_in... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Finaliz... | 98     | 0.003  | 0.012 | 1.167   | 0.2%   | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | p... | ... | ... | fe... | d... | l | s... | d | t | f... | (v | d... |
# ...
# INFO  {'process': 'gptq', 'layer': 13, 'module': 'self_attn.o_proj', 'feat: in, out': '2048, 2048', 'dtype: size': 'bf16: 8.3MB', 'loss': '0.0000001032', 'samples': '454766', 'damp': '0.05000', 'time': '0.204', 'fwd_time': '0.947', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 13, 'module': 'mlp.gate_proj', 'feat: in, out': '2048, 8192', 'dtype: size': 'bf16: 33.0MB', 'loss': '0.0000194857', 'samples': '454766', 'damp': '0.05000', 'time': '0.506', 'fwd_time': '2.120', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 13, 'module': 'mlp.up_proj', 'feat: in, out': '2048, 8192', 'dtype: size': 'bf16: 33.0MB', 'loss': '0.0000140965', 'samples': '454766', 'damp': '0.05000', 'time': '0.519', 'fwd_time': '2.120', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 13, 'module': 'mlp.down_proj', 'feat: in, out': '8192, 2048', 'dtype: size': 'bf16: 33.0MB', 'loss': '0.0000006395', 'samples': '454766', 'damp': '0.05000', 'time': '1.018', 'fwd_time': '8.758', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 14, 'module': 'self_attn.v_proj', 'feat: in, out': '2048, 512', 'dtype: size': 'bf16: 2.1MB', 'loss': '0.0000035810', 'samples': '454766', 'damp': '0.05000', 'time': '0.804', 'fwd_time': '1.620', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 14, 'module': 'self_attn.k_proj', 'feat: in, out': '2048, 512', 'dtype: size': 'bf16: 2.1MB', 'loss': '0.0000070012', 'samples': '454766', 'damp': '0.05000', 'time': '0.814', 'fwd_time': '1.620', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 14, 'module': 'self_attn.q_proj', 'feat: in, out': '2048, 2048', 'dtype: size': 'bf16: 8.3MB', 'loss': '0.0000139711', 'samples': '454766', 'damp': '0.05000', 'time': '0.829', 'fwd_time': '1.620', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 14, 'module': 'self_attn.o_proj', 'feat: in, out': '2048, 2048', 'dtype: size': 'bf16: 8.3MB', 'loss': '0.0000002490', 'samples': '454766', 'damp': '0.05000', 'time': '0.205', 'fwd_time': '0.958', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 14, 'module': 'mlp.up_proj', 'feat: in, out': '2048, 8192', 'dtype: size': 'bf16: 33.0MB', 'loss': '0.0000159140', 'samples': '454766', 'damp': '0.05000', 'time': '0.685', 'fwd_time': '2.131', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 14, 'module': 'mlp.gate_proj', 'feat: in, out': '2048, 8192', 'dtype: size': 'bf16: 33.0MB', 'loss': '0.0000234714', 'samples': '454766', 'damp': '0.05000', 'time': '0.691', 'fwd_time': '2.131', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 14, 'module': 'mlp.down_proj', 'feat: in, out': '8192, 2048', 'dtype: size': 'bf16: 33.0MB', 'loss': '0.0000009002', 'samples': '454766', 'damp': '0.05000', 'time': '1.011', 'fwd_time': '8.733', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 15, 'module': 'self_attn.q_proj', 'feat: in, out': '2048, 2048', 'dtype: size': 'bf16: 8.3MB', 'loss': '0.0000128856', 'samples': '454766', 'damp': '0.05000', 'time': '0.834', 'fwd_time': '1.618', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 15, 'module': 'self_attn.v_proj', 'feat: in, out': '2048, 512', 'dtype: size': 'bf16: 2.1MB', 'loss': '0.0000036949', 'samples': '454766', 'damp': '0.05000', 'time': '0.839', 'fwd_time': '1.618', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 15, 'module': 'self_attn.k_proj', 'feat: in, out': '2048, 512', 'dtype: size': 'bf16: 2.1MB', 'loss': '0.0000076672', 'samples': '454766', 'damp': '0.05000', 'time': '0.852', 'fwd_time': '1.618', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 15, 'module': 'self_attn.o_proj', 'feat: in, out': '2048, 2048', 'dtype: size': 'bf16: 8.3MB', 'loss': '0.0000009990', 'samples': '454766', 'damp': '0.05000', 'time': '0.202', 'fwd_time': '0.955', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 15, 'module': 'mlp.up_proj', 'feat: in, out': '2048, 8192', 'dtype: size': 'bf16: 33.0MB', 'loss': '0.0000197593', 'samples': '454766', 'damp': '0.05000', 'time': '0.601', 'fwd_time': '2.137', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 15, 'module': 'mlp.gate_proj', 'feat: in, out': '2048, 8192', 'dtype: size': 'bf16: 33.0MB', 'loss': '0.0000262429', 'samples': '454766', 'damp': '0.05000', 'time': '0.605', 'fwd_time': '2.137', '(v)ram': 'n/a'}
# INFO  {'process': 'gptq', 'layer': 15, 'module': 'mlp.down_proj', 'feat: in, out': '8192, 2048', 'dtype: size': 'bf16: 33.0MB', 'loss': '0.0000029965', 'samples': '454766', 'damp': '0.05000', 'time': '1.022', 'fwd_time': '8.900', '(v)ram': 'n/a'}
# INFO  | Pre-qua... | 64     | 8.900  | 3.375 | 215.989 | 36.6%  | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Forward... | 114688 | 0.002  | 0.001 | 133.963 | 22.7%  | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Submodu... | 112    | 0.098  | 0.864 | 96.730  | 16.4%  | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Process... | 112    | 1.027  | 0.697 | 78.044  | 13.2%  | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Finaliz... | 112    | 0.058  | 0.226 | 25.356  | 4.3%   | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Post-qu... | 15     | 1.577  | 1.581 | 23.719  | 4.0%   | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Finaliz... | 112    | 0.030  | 0.107 | 11.945  | 2.0%   | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Capture... | 1      | 3.314  | 3.314 | 3.314   | 0.6%   | cache_in... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Finaliz... | 112    | 0.006  | 0.012 | 1.320   | 0.2%   | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Process... | 1      | 0.000  | 0.000 | 0.000   | 0.0%   | gptq        |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# Writing model shards: 0it [00:00, ?it/s]
# INFO  Saved Quantize Config:
# {
#   "bits": 4,
#   "group_size": 128,
#   "desc_act": false,
#   "lm_head": false,
#   "method": "gptq",
#   "quant_method": "gptq",
#   "format": "gptq",
#   "checkpoint_format": "gptq",
#   "pack_dtype": "int32",
#   "meta": {
#     "quantizer": [
#       "gptqmodel:7.3.2"
#     ],
#     "uri": "https://github.com/modelcloud/gptqmodel",
#     "damp_percent": 0.05,
#     "damp_auto_increment": 0.01,
#     "static_groups": false,
#     "true_sequential": true,
#     "mse": 0.0,
#     "gptaq": null,
#     "foem": null,
#     "act_group_aware": true,
#     "fallback": {
#       "strategy": "rtn",
#       "threshold": "0.5%",
#       "smooth": null
#     },
#     "offload_to_disk": true,
#     "offload_to_disk_path": "/tmp/gptqmodel_ark4ak32",
#     "pack_impl": "cpu",
#     "gc_mode": "interval",
#     "wait_for_submodule_finalizers": false,
#     "auto_forward_data_parallel": true,
#     "dense_vram_strategy": "exclusive",
#     "dense_vram_strategy_devices": null,
#     "moe_vram_strategy": "exclusive",
#     "moe_vram_strategy_devices": null,
#     "mock_quantization": false,
#     "hessian": {
#       "chunk_size": null,
#       "chunk_bytes": null,
#       "staging_dtype": "float32"
#     }
#   },
#   "sym": true
# }
# Files in directory:
# config.json
# quantize_config.json
# generation_config.json
# quant_log.csv
# Content of saved `generation_config.json`:
# {
#     "bos_token_id": 128000,
#     "do_sample": true,
#     "eos_token_id": [
#         128001,
#         128008,
#         128009
#     ],
#     "max_length": 131072,
#     "pad_token_id": 128004,
#     "temperature": 0.6,
#     "top_p": 0.9,
#     "transformers_version": "5.14.1"
# }
# Content of saved `config.json`:
# {
#     "architectures": [
#         "LlamaForCausalLM"
#     ],
#     "attention_bias": false,
#     "attention_dropout": 0.0,
#     "bos_token_id": 128000,
#     "dtype": "bfloat16",
#     "eos_token_id": 128009,
#     "head_dim": 64,
#     "hidden_act": "silu",
#     "hidden_size": 2048,
#     "initializer_range": 0.02,
#     "intermediate_size": 8192,
#     "max_position_embeddings": 131072,
#     "mlp_bias": false,
#     "model_type": "llama",
#     "num_attention_heads": 32,
#     "num_hidden_layers": 16,
#     "num_key_value_heads": 8,
#     "pad_token_id": 128004,
#     "pretraining_tp": 1,
#     "quantization_config": {
#         "bits": 4,
#         "checkpoint_format": "gptq",
#         "desc_act": false,
#         "format": "gptq",
#         "group_size": 128,
#         "lm_head": false,
#         "meta": {
#             "act_group_aware": true,
#             "auto_forward_data_parallel": true,
#             "damp_auto_increment": 0.01,
#             "damp_percent": 0.05,
#             "dense_vram_strategy": "exclusive",
#             "dense_vram_strategy_devices": null,
#             "fallback": {
#                 "smooth": null,
#                 "strategy": "rtn",
#                 "threshold": "0.5%"
#             },
#             "foem": null,
#             "gc_mode": "interval",
#             "gptaq": null,
#             "hessian": {
#                 "chunk_bytes": null,
#                 "chunk_size": null,
#                 "staging_dtype": "float32"
#             },
#             "mock_quantization": false,
#             "moe_vram_strategy": "exclusive",
#             "moe_vram_strategy_devices": null,
#             "mse": 0.0,
#             "offload_to_disk": true,
#             "offload_to_disk_path": "/tmp/gptqmodel_ark4ak32",
#             "pack_impl": "cpu",
#             "quantizer": [
#                 "gptqmodel:7.3.2"
#             ],
#             "static_groups": false,
#             "true_sequential": true,
#             "uri": "https://github.com/modelcloud/gptqmodel",
#             "wait_for_submodule_finalizers": false
#         },
#         "method": "gptq",
#         "pack_dtype": "int32",
#         "quant_method": "gptq",
#         "sym": true
#     },
#     "rms_norm_eps": 1e-05,
#     "rope_parameters": {
#         "factor": 32.0,
#         "high_freq_factor": 4.0,
#         "low_freq_factor": 1.0,
#         "original_max_position_embeddings": 8192,
#         "rope_theta": 500000.0,
#         "rope_type": "llama3"
#     },
#     "tie_word_embeddings": true,
#     "transformers_version": "5.14.1",
#     "unsloth_fixed": true,
#     "use_cache": true,
#     "vocab_size": 128256
# }
# INFO  Module: Re-tied embedding weights on shell model after lazy sync
# INFO  Module: Total direct tensors materialized from lazy checkpoint source: 1
# INFO  Pre-Quantized model size: 2357.14MB, 2.30GB
# INFO  Quantized model size: 984.55MB, 0.96GB
# INFO  Size difference: 1372.59MB, 1.34GB - 58.23%
# INFO  | Pre-qua... | 64     | 8.900  | 3.375 | 215.989 | 36.5%  | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Forward... | 114688 | 0.002  | 0.001 | 133.963 | 22.7%  | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Submodu... | 112    | 0.098  | 0.864 | 96.730  | 16.4%  | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Process... | 112    | 1.027  | 0.697 | 78.044  | 13.2%  | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Finaliz... | 112    | 0.058  | 0.226 | 25.356  | 4.3%   | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Post-qu... | 15     | 1.577  | 1.581 | 23.719  | 4.0%   | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Finaliz... | 112    | 0.030  | 0.107 | 11.945  | 2.0%   | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Capture... | 1      | 3.314  | 3.314 | 3.314   | 0.6%   | cache_in... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Finaliz... | 112    | 0.006  | 0.012 | 1.320   | 0.2%   | model.la... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Model save | 1      | 0.918  | 0.918 | 0.918   | 0.2%   | /home/an... |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# INFO  | Process... | 1      | 0.000  | 0.000 | 0.000   | 0.0%   | gptq        |
# INFO  +------------+--------+--------+-------+---------+--------+-------------+
# from_quantized: adapter: None
# INFO  Loader: Auto dtype (native bfloat16): `torch.bfloat16`
# INFO  Estimated Quantization BPW (bits per weight): 4.2875 bpw, based on [bits: 4, group_size: 128]
# INFO:tokenicer.tokenicer:Tokenicer: Auto fixed pad_token_id=128004 (token='<|finetune_right_pad_id|>').
# INFO  The layer model.embed_tokens is not quantized.
# INFO  Kernel: Auto-selection: adding candidate `MarlinLinear`
# INFO  Kernel: Auto-selection: adding candidate `ExllamaV2Linear`
# INFO  Kernel: Auto-selection: adding candidate `TritonV2Linear`
# INFO  Kernel: Auto-selection: adding candidate `TorchLinear`
# INFO  Kernel: candidates -> `[MarlinLinear, ExllamaV2Linear, TritonV2Linear, TorchLinear]`
# INFO  Kernel: per-module selections -> `[MarlinLinear=112]`
# INFO  Kernel: selected -> `MarlinLinear`.
# INFO  Loader: device = DEVICE.CUDA
# INFO  Loader: honoring explicit device_map request: {'': 'cuda:0'}
# INFO  Loader: device_map = {'': 'cuda:0'}
# WARNING:accelerate.utils.modeling:The model weights are not tied. Please use the `tie_weights` method before using the `infer_auto_device` function.
# INFO  Kernel: Auto-selection: adding candidate `MarlinLinear`
# INFO  Kernel: selected -> `MarlinLinear`.
# INFO  gc.collect() reclaimed 3 objects in 0.244s
# INFO:tokenicer.tokenicer:Tokenicer: Auto fixed pad_token_id=128004 (token='<|finetune_right_pad_id|>').
# INFO  Model: Loaded `generation_config`: GenerationConfig {
#   "bos_token_id": 128000,
#   "eos_token_id": 128009,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "pad_token_id": 128004,
#   "use_cache": true
# }
#
# INFO  Model: Auto-fixed `generation_config` mismatch between model and `generation_config.json`.
# INFO  Model: Updated `generation_config`: GenerationConfig {
#   "bos_token_id": 128000,
#   "do_sample": true,
#   "eos_token_id": [
#     128001,
#     128008,
#     128009
#   ],
#   "max_length": 131072,
#   "pad_token_id": 128004,
#   "temperature": 0.6,
#   "top_p": 0.9
# }
#
# INFO  Kernel: loaded -> `[MarlinLinear]`
# Evaluating normal model...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[34], line 70
#      66     ppl_quant = calculate_avg_ppl(quant_model, quant_model.tokenizer, eval_texts)
#      67     print("Quantized model avg PPL:", ppl_quant)
#      68
#      69 if __name__ == "__main__":
# ---> 70     main()
#
# Cell In[34], line 61, in main()
#      57         quant_model = load_quant_model(quant_path, device=device)
#      58
#      59     # Evaluate normal model
#      60     print("Evaluating normal model...")
# ---> 61     ppl_normal = calculate_avg_ppl(normal_model, normal_model.tokenizer, eval_texts)
#      62     print("Normal model avg PPL:", ppl_normal)
#      63
#      64     # Evaluate quantized model
#
# Cell In[34], line 7, in calculate_avg_ppl(model, tokenizer, texts, max_length, batch_size)
#       5 def calculate_avg_ppl(model, tokenizer, texts, max_length=512, batch_size=8):
#       6     """Compute average perplexity over a list of plain text strings."""
# ----> 7     from gptqmodel.utils.perplexity import Perplexity
#       8
#       9     ppl = Perplexity(
#      10         model=model,
#
# ModuleNotFoundError: No module named 'gptqmodel.utils.perplexity'
